# %% [markdown]
# TP 5 - Rendu

# %% [markdown]
# # Localisation et détection d'objet
#
# Dans ce TP, nous allons mettre en pratique certaines des méthodes présentées en cours pour localiser des objets dans une image.
#
# En localisation et détection, on cherche à déterminer la position d'un objet, ainsi que sa classe, sous la forme d'une boîte englobante de largeur $b_w$ et hauteur $b_h$, et dont le centre a pour coordonnées le point $(b_x, b_y)$.
#
# <center> <img src="https://drive.google.com/uc?id=1_jHHv6ZDe-3Xz25jIZ6o177laBEfmMRR" style="width:500;height:300px;"></center>
# <caption><center> Figure 1: Modèle de boîte englobante utilisé pour la localisation </center></caption>
#
# Le problème de localisation considère qu'un seul objet est présent sur l'image, alors que le problème de détection cherche à déterminer l'ensemble des objets présents sur l'image.
#
#
#
# Pour commencer, récupérez les images de la base de données :

# %%
# !git clone https://github.com/axelcarlier/wildlife.git
# Out:
# Cloning into 'wildlife'...
# remote: Enumerating objects: 2973, done.
# remote: Total 2973 (delta 0), reused 0 (delta 0), pack-reused 2973
# Receiving objects: 100% (2973/2973), 433.18 MiB | 45.86 MiB/s, done.
# Checking out files: 100% (3008/3008), done.

# %% [markdown]
# La base de données comporte 4 classes, pour les 4 animaux suivants : buffle, éléphant, rhinocéros et zèbre.
#
# <center> <img src="https://drive.google.com/uc?id=1sej2InBiQDEmpk2RA7S2dLRsJvF_UszE" width=200>
# <img src="https://drive.google.com/uc?id=1K8cO4plzVIXO1MC4mkRcFIFjgspHtOIm" width=200>
# <img src="https://drive.google.com/uc?id=15pkHpPW_VR1joOyPryS1pavOTqmoNR88" width=200>
# <img src="https://drive.google.com/uc?id=19zHZn-A_j8Sx0G3V2SwR_YNKF0dGI1NA" width=200></center>
# <caption><center> Figure 2: Exemples d'images de la base de données </center></caption>

# %% [markdown]
# # Localisation et classification d'objet
#
# Dans cette partie, nous allons nous concentrer sur le problème de la localisation d'un seul objet par classe. Pour le cas où il y aurait plusieurs objets sur la même image, nous considérerons uniquement l'objet dont la boîte englobante occupe la plus grande surface sur l'image.

# %% [markdown]
# ## Préparation des données
#
# La fonction ci-dessous permet de charger les données et les formater pour la classification. Prenez le temps de regarder un peu le format des labels $y$.

# %%
import PIL
from PIL import Image
import os, sys
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import keras
from keras.utils import np_utils

# La base de données contient 376 images de chacune des 4 classes
DATASET_SIZE = 376*4
# Nous choisissons ici la dimension dans laquelle nous allons redimensionner les images
# 64x64 est une dimension assez faible mais qui nous permettra d'avoir des expériences plus rapides
# 128x128 ou 256x256 permettraient d'avoir de meilleurs résultats mais au prix de plusieurs heures d'entraînement
IMAGE_SIZE = 64

def load_data_localization(image_size):
  # Chemin vers la base de données
  ds_path = "/content/wildlife/"
  # Chemins vers les données des 4 différentes classes
  paths = [ds_path + "buffalo/", ds_path + "elephant/", ds_path + "rhino/", ds_path + "zebra/"]
  # Indice d'ajout de données dans les variables x et y 
  i = 0
  # Préparation des structures de données pour x et y
  x = np.zeros((DATASET_SIZE, image_size, image_size, 3))
  y = np.empty((DATASET_SIZE, 9)) # 9 = 1 + 4 + 4 : présence / boîte englobante / classes
    
  # Parcours des chemins de chacune des classes
  for path in paths:

    # Parcours des fichiers (classés) du répertoire
    dirs = os.listdir(path)
    dirs.sort()

    for item in dirs:

      if os.path.isfile(path + item):
        # Extraction de l'extension du fichier 
        extension =item.split(".")[1]

        if extension=="jpg" or extension=="JPG":
          # Image : on va remplir la variable x
          # Lecture de l'image
          img = Image.open(path + item)
          # Mise à l'échelle de l'image
          img = img.resize((image_size,image_size), Image.ANTIALIAS)
          # Remplissage de la variable x
          x[i] = np.asarray(img)

        elif extension=="txt":
          # Fichier Texte : coordonnées de boîtes englobantes pour remplir y
          labels = open(path + item, "r")
          # Récupération des lignes du fichier texte
          labels= labels.read().split('\n')
          # Si la dernière ligne est vide, la supprimer 
          if labels[-1]=="":
            del labels[-1]

          # Indice de la boîte englobante de surface maximale
          j_max = 0
          if len(labels) > 1:
            aire_max = 0 # Surface de la boîte englobante de surface maximale
            # Parcours des boîtes englobantes des objets présents sur l'image
            for j in range(len(labels)):
              # Calcul de l'aire de la boîte englobante courante
              aire = float(labels[j].split()[3]) * float(labels[j].split()[4])
              # Mise à jour de la boîte englobante de surface maximale, si nécessaire
              if aire > aire_max:
                aire_max = aire
                j_max = j    

          # Un objet est présent sur l'image (presence = 1)
          presence = np.array([1], dtype="i")
          # "One-hot vector" représentant les probabilités de classe
          classes = np_utils.to_categorical(labels[j_max].split()[0], num_classes=4)
          # Coordonnées de la boîte englobante de surface maximale
          coordonnees = np.array(labels[j_max].split()[1:], dtype="f")
          # Remplissage de la variable y
          y[i, 0] = presence
          y[i, 1:5] = coordonnees
          y[i, 5:] = classes

          i = i + 1
        else:
          print("extension trouvée : ", extension)

  return x, y

x,y = load_data_localization(IMAGE_SIZE)

# %% [markdown]
# Séparation des données en ensembles d'entraînement et de validation

# %%
from sklearn.model_selection import train_test_split

x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.15, random_state=42)

# Pour améliorer l'entraînement, on peut centrer-réduire les coordonnées des bounding boxes
y_std = np.std(y_train, axis=0)
y_mean = np.mean(y_train, axis=0)
y_train[...,1:5] = (y_train[...,1:5] - y_mean[1:5])/y_std[1:5]
y_val[...,1:5] = (y_val[...,1:5] - y_mean[1:5])/y_std[1:5]

# Et normaliser les valeurs de couleur
x_train = x_train/255
x_val = x_val/255

# %%
# Tests
print("shape of x_train", np.shape(x_train))
print("shape of y_train", np.shape(y_train))
print("shape of x_val", np.shape(x_val))
print("shape of y_val", np.shape(y_val))
# Out:
# shape of x_train (1278, 64, 64, 3)
# shape of y_train (1278, 9)
# shape of x_val (226, 64, 64, 3)
# shape of y_val (226, 9)

# %% [markdown]
# ## Fonctions utiles

# %% [markdown]
# Calcul du coefficient de Jaccard (intersection sur union) entre boîtes englobantes réelles et prédites.

# %%
def compute_iou(y_true, y_pred):
  ### "Dénormalisation" des coordonnées des boîtes englobantes
  pred_box_xy = y_pred[..., 0:2]* y_std[0:2] + y_mean[0:2]
  true_box_xy = y_true[..., 0:2]* y_std[0:2] + y_mean[0:2]

  ### "Dénormalisation" des largeur et hauteur des boîtes englobantes
  pred_box_wh = y_pred[..., 2:4] * y_std[2:4] + y_mean[2:4]
  true_box_wh = y_true[..., 2:4] * y_std[2:4] + y_mean[2:4]
  
  # Calcul des coordonnées minimales et maximales des boiptes englobantes réelles
  true_wh_half = true_box_wh / 2.
  true_mins    = true_box_xy - true_wh_half
  true_maxes   = true_box_xy + true_wh_half
  
  # Calcul des coordonnées minimales et maximales des boiptes englobantes prédites
  pred_wh_half = pred_box_wh / 2.
  pred_mins    = pred_box_xy - pred_wh_half
  pred_maxes   = pred_box_xy + pred_wh_half       
  
  # Détermination de l'intersection des boîtes englobantes
  intersect_mins  = tf.maximum(pred_mins,  true_mins)
  intersect_maxes = tf.minimum(pred_maxes, true_maxes)
  intersect_wh    = tf.maximum(intersect_maxes - intersect_mins, 0.)
  intersect_areas = intersect_wh[..., 0] * intersect_wh[..., 1]
  
  # Aire des boîtes englobantes prédites et réelles
  true_areas = true_box_wh[..., 0] * true_box_wh[..., 1]
  pred_areas = pred_box_wh[..., 0] * pred_box_wh[..., 1]

  # Aire de l'union des boîtes prédites et réelles
  union_areas = pred_areas + true_areas - intersect_areas

  iou_scores  = tf.truediv(intersect_areas, union_areas)
  return iou_scores

def iou():
  def iou_metrics(y_true, y_pred):
    return compute_iou(y_true, y_pred)
  iou_metrics.__name__= "IoU"
  return iou_metrics

# %% [markdown]
# Visualisation des données et labels

# %%
# Si seuls x et y sont indiqués, on tire au hasard un numéro d'image et on affiche le label y associé  à l'image
# Si un 2e y, nommé y_pred, est indiqué, alors les deux labels sont affichés côte à côte, afin de pouvoir les comparer
# Enfin on peut également indiquer l'id de l'image que l'on souhaite visualiser.
def print_data_localisation(x, y, y_pred=[], id=None, image_size=IMAGE_SIZE):
  if id==None:
    # Tirage aléatoire d'une image dans la base
    num_img = np.random.randint(x.shape[0]-1)
  else:
    num_img = id

  img = x[num_img]
  lab = y[num_img]

  colors = ["blue", "yellow", "red", "orange"] # Différentes couleurs pour les différentes classes
  classes = ["Buffalo", "Elephant", "Rhino", "Zebra"]

  if np.any(y_pred):
    plt.subplot(1, 2, 1)

  # Affichage de l'image
  plt.imshow(img)
  # Détermination de la classe
  class_id = np.argmax(lab[5:])

  # Détermination des coordonnées de la boîte englobante dans le repère image
  ax = (lab[1]*y_std[1] + y_mean[1]) * image_size
  ay = (lab[2]*y_std[2] + y_mean[2]) * image_size
  width = (lab[3]*y_std[3] + y_mean[3]) * image_size
  height = (lab[4]*y_std[4] + y_mean[4]) * image_size
  #print("x: {}, y: {}, w: {}, h:{}".format(ax,ay,width, height))
  # Détermination des extrema de la boîte englobante
  p_x = [ax-width/2, ax+width/2]
  p_y = [ay-height/2, ay+height/2]
  # Affichage de la boîte englobante, dans la bonne couleur
  plt.plot([p_x[0], p_x[0]],p_y,color=colors[class_id])
  plt.plot([p_x[1], p_x[1]],p_y,color=colors[class_id])
  plt.plot(p_x,[p_y[0],p_y[0]],color=colors[class_id])
  plt.plot(p_x,[p_y[1],p_y[1]],color=colors[class_id])
  plt.title("Vérité Terrain : Image {} - {}".format(num_img, classes[class_id]))

  if np.any(y_pred):
    plt.subplot(1, 2, 2)
    # Affichage de l'image
    plt.imshow(img)
    lab = y_pred[num_img]
    # Détermination de la classe
    class_id = np.argmax(lab[5:])

    # Détermination des coordonnées de la boîte englobante dans le repère image
    ax = (lab[1]*y_std[1] + y_mean[1]) * image_size
    ay = (lab[2]*y_std[2] + y_mean[2]) * image_size
    width = (lab[3]*y_std[3] + y_mean[3]) * image_size
    height = (lab[4]*y_std[4] + y_mean[4]) * image_size
    #print("x: {}, y: {}, w: {}, h:{}".format(ax,ay,width, height))
    # Détermination des extrema de la boîte englobante
    p_x = [ax-width/2, ax+width/2]
    p_y = [ay-height/2, ay+height/2]
    # Affichage de la boîte englobante, dans la bonne couleur
    plt.plot([p_x[0], p_x[0]],p_y,color=colors[class_id])
    plt.plot([p_x[1], p_x[1]],p_y,color=colors[class_id])
    plt.plot(p_x,[p_y[0],p_y[0]],color=colors[class_id])
    plt.plot(p_x,[p_y[1],p_y[1]],color=colors[class_id])
    plt.title("Prédiction : Image {} - {}".format(num_img, classes[class_id]))


  plt.show()

print_data_localisation(x_train, y_train, image_size=IMAGE_SIZE)

# %%
def plot_training_analysis(history, metric='loss'):    

  loss = history.history[metric]
  val_loss = history.history['val_' + metric]

  epochs = range(len(loss))

  plt.plot(epochs, loss, 'b', linestyle="--",label='Training ' + metric)
  plt.plot(epochs, val_loss, 'g', label='Validation ' + metric)
  plt.title('Training and validation ' + metric)
  plt.legend()

  plt.show()

# %% [markdown]
# ## Travail à faire

# %% [markdown]
# <center> <img src="https://drive.google.com/uc?id=1YzCZe4pgnjJDVGklAaCHZ7HhlPJsadg9" width=500></center>
# <caption><center> Figure 3: Illustration de l'architecture du réseau à construire.  </center></caption>
#
# Complétez les codes qui vous sont fournis pour obtenir un algorithme de localisation.
# Vous pouvez utiliser n'importe quelle base convolutive de votre choix, en revanche vous devrez porter une attention particulière à la couche de sortie.
#
# Vous allez en fait produire 3 sorties différentes : une caractérisant la présence d'un objet, une autre fournissant les coordonnées de la boîte englobante, et enfin une dernière effectuant la classification.

# %%
import keras
from keras import layers
from keras import models
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, Input, BatchNormalization
from keras.layers.advanced_activations import LeakyReLU
from keras.models import Model, Sequential

def create_model_localisation(input_shape=(64, 64, 3)):

  input_layer = Input(shape=input_shape)


  conv1 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(input_layer)
  pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
  
  # Couche 1
  x = conv1
  x = BatchNormalization(name='norm_1')(x)
  x = LeakyReLU(alpha=0.1)(x)
  x = MaxPooling2D(pool_size=(2, 2))(x)

  # Couche 2
  x = Conv2D(1024, (3,3), strides=(1,1), padding='same', use_bias=False)(x)
  x = BatchNormalization()(x)
  x = LeakyReLU(alpha=0.1)(x)

  # Couche 3
  x = Conv2D(1024, (3,3), strides=(1,1), padding='same', use_bias=False)(x)
  x = BatchNormalization()(x)
  x = LeakyReLU(alpha=0.1)(x)

  # Couche 4
  x = Conv2D(1024, (3,3), strides=(1,1), padding='same', use_bias=False)(x)
  x = BatchNormalization()(x)
  x = LeakyReLU(alpha=0.1)(x)

  # Couche 5
  x = Conv2D((9), (1,1), strides=(1,1), padding='same')(x)
  x = BatchNormalization()(x)
  x = LeakyReLU(alpha=0.1)(x)

  x = Flatten()(x)
    
  output_p = Dense(1, activation='sigmoid', name='p')(x)
  output_coord = Dense(4, activation='linear', name='coord')(x)
  output_class = Dense(4, activation='softmax', name='classes')(x)
  
  output= [output_p, output_coord, output_class]
  model = Model(input_layer, output)

  return model

# %% [markdown]
# <center> <img src="https://drive.google.com/uc?id=1bnh8zU7Os-w-5TT8hV4xDoThKQc-Ywc2" width=500></center>
# <caption><center> Figure 4: Illustration des fonctions de coût à utiliser pour l'entraînement. </center></caption>
#
# Pour entraîner votre réseau, vous allez donc devoir associer une fonction de coût à chacune des sorties du réseau. La fonction de coût totale sera la somme des trois fonctions de coût précédemment définies, pondérées par des poids définis dans la variable *loss_weights*.
#
# **Prenez le temps de tester différentes valeurs de *loss_weights* en fonction de l'évolution des métriques que vous observerez pendant l'entraînement.**

# %% [markdown]
# Considérant que le plus important est de trouver la bonne classe ,on augmente le poid associé à la détection de la bonne classe

# %%
from keras.optimizers import Adam

import tensorflow as tf



batch_size=16
model = create_model_localisation()
print("model shape", np.shape(model))
opt = Adam(learning_rate=3e-4)  

loss=[tf.keras.losses.BinaryCrossentropy(), tf.keras.losses.MeanSquaredError(), tf.keras.losses.BinaryCrossentropy()]
metrics=[ ['accuracy'], [iou()], ['accuracy']]
loss_weights = [1, 1, 2]

model.compile(loss=loss,
              optimizer=opt,
              metrics=metrics,
              loss_weights=loss_weights
              )

model.summary()

history = model.fit(x_train, [y_train[:,0], y_train[:,1:5], y_train[:,5:9]],
              epochs=30,
              batch_size=batch_size,            
              validation_data=(x_val, [y_val[:,0], y_val[:,1:5], y_val[:,5:9]]))
# Out:
# model shape ()
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64, 64, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 64, 64, 32)   896         input_1[0][0]
# __________________________________________________________________________________________________
# norm_1 (BatchNormalization)     (None, 64, 64, 32)   128         conv2d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 64, 64, 32)   0           norm_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 32)   0           leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 1024) 294912      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 32, 32, 1024) 4096        conv2d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 32, 32, 1024) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 1024) 9437184     leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 1024) 4096        conv2d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 32, 32, 1024) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 1024) 9437184     leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 1024) 4096        conv2d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 32, 32, 1024) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 9)    9225        leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 9)    36          conv2d_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 32, 32, 9)    0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 9216)         0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# p (Dense)                       (None, 1)            9217        flatten[0][0]
# __________________________________________________________________________________________________
# coord (Dense)                   (None, 4)            36868       flatten[0][0]
# __________________________________________________________________________________________________
# classes (Dense)                 (None, 4)            36868       flatten[0][0]
# ==================================================================================================
# Total params: 19,274,806
# Trainable params: 19,268,580
# Non-trainable params: 6,226
# __________________________________________________________________________________________________
# Epoch 1/30
# 80/80 [==============================] - 23s 179ms/step - loss: 2.8318 - p_loss: 0.0531 - coord_loss: 1.6029 - classes_loss: 0.5879 - p_accuracy: 0.9693 - coord_IoU: 0.5099 - classes_accuracy: 0.3518 - val_loss: 2.4813 - val_p_loss: 0.0013 - val_coord_loss: 1.3199 - val_classes_loss: 0.5801 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.4568 - val_classes_accuracy: 0.2743
# Epoch 2/30
# 80/80 [==============================] - 13s 162ms/step - loss: 1.6075 - p_loss: 4.1161e-04 - coord_loss: 0.7713 - classes_loss: 0.4179 - p_accuracy: 1.0000 - coord_IoU: 0.6180 - classes_accuracy: 0.6093 - val_loss: 2.7859 - val_p_loss: 3.9671e-04 - val_coord_loss: 1.4508 - val_classes_loss: 0.6673 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.4180 - val_classes_accuracy: 0.2301
# Epoch 3/30
# 80/80 [==============================] - 13s 164ms/step - loss: 1.3637 - p_loss: 3.1648e-04 - coord_loss: 0.6688 - classes_loss: 0.3473 - p_accuracy: 1.0000 - coord_IoU: 0.6378 - classes_accuracy: 0.6980 - val_loss: 2.6545 - val_p_loss: 2.5962e-04 - val_coord_loss: 1.2133 - val_classes_loss: 0.7205 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5005 - val_classes_accuracy: 0.2345
# Epoch 4/30
# 80/80 [==============================] - 13s 166ms/step - loss: 1.1481 - p_loss: 1.7832e-04 - coord_loss: 0.5249 - classes_loss: 0.3115 - p_accuracy: 1.0000 - coord_IoU: 0.6576 - classes_accuracy: 0.7321 - val_loss: 2.0422 - val_p_loss: 1.8913e-04 - val_coord_loss: 0.9754 - val_classes_loss: 0.5333 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5830 - val_classes_accuracy: 0.4159
# Epoch 5/30
# 80/80 [==============================] - 13s 166ms/step - loss: 0.9443 - p_loss: 2.1046e-04 - coord_loss: 0.4375 - classes_loss: 0.2533 - p_accuracy: 1.0000 - coord_IoU: 0.6832 - classes_accuracy: 0.8286 - val_loss: 1.8592 - val_p_loss: 2.9452e-04 - val_coord_loss: 0.8458 - val_classes_loss: 0.5065 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6199 - val_classes_accuracy: 0.4735
# Epoch 6/30
# 80/80 [==============================] - 13s 167ms/step - loss: 0.7513 - p_loss: 1.0123e-04 - coord_loss: 0.3343 - classes_loss: 0.2085 - p_accuracy: 1.0000 - coord_IoU: 0.6974 - classes_accuracy: 0.8617 - val_loss: 1.7529 - val_p_loss: 1.6736e-04 - val_coord_loss: 0.8361 - val_classes_loss: 0.4583 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6129 - val_classes_accuracy: 0.5265
# Epoch 7/30
# 80/80 [==============================] - 14s 169ms/step - loss: 0.6066 - p_loss: 5.8679e-05 - coord_loss: 0.2536 - classes_loss: 0.1764 - p_accuracy: 1.0000 - coord_IoU: 0.7463 - classes_accuracy: 0.8973 - val_loss: 1.6818 - val_p_loss: 1.2560e-04 - val_coord_loss: 0.8990 - val_classes_loss: 0.3914 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5705 - val_classes_accuracy: 0.6283
# Epoch 8/30
# 80/80 [==============================] - 14s 170ms/step - loss: 0.4888 - p_loss: 3.9825e-05 - coord_loss: 0.2203 - classes_loss: 0.1343 - p_accuracy: 1.0000 - coord_IoU: 0.7505 - classes_accuracy: 0.9515 - val_loss: 1.5509 - val_p_loss: 3.3856e-05 - val_coord_loss: 0.8078 - val_classes_loss: 0.3715 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6258 - val_classes_accuracy: 0.6637
# Epoch 9/30
# 80/80 [==============================] - 14s 171ms/step - loss: 0.4348 - p_loss: 2.9220e-05 - coord_loss: 0.2004 - classes_loss: 0.1172 - p_accuracy: 1.0000 - coord_IoU: 0.7632 - classes_accuracy: 0.9576 - val_loss: 1.6764 - val_p_loss: 7.0664e-05 - val_coord_loss: 0.9271 - val_classes_loss: 0.3746 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5939 - val_classes_accuracy: 0.6504
# Epoch 10/30
# 80/80 [==============================] - 14s 172ms/step - loss: 0.3745 - p_loss: 3.8415e-05 - coord_loss: 0.1983 - classes_loss: 0.0881 - p_accuracy: 1.0000 - coord_IoU: 0.7608 - classes_accuracy: 0.9820 - val_loss: 1.7966 - val_p_loss: 2.1600e-05 - val_coord_loss: 0.9923 - val_classes_loss: 0.4021 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6054 - val_classes_accuracy: 0.6460
# Epoch 11/30
# 80/80 [==============================] - 14s 172ms/step - loss: 0.2922 - p_loss: 2.9012e-05 - coord_loss: 0.1517 - classes_loss: 0.0703 - p_accuracy: 1.0000 - coord_IoU: 0.7844 - classes_accuracy: 0.9906 - val_loss: 1.6621 - val_p_loss: 4.3925e-05 - val_coord_loss: 0.9267 - val_classes_loss: 0.3677 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6100 - val_classes_accuracy: 0.6814
# Epoch 12/30
# 80/80 [==============================] - 14s 172ms/step - loss: 0.2432 - p_loss: 2.6329e-05 - coord_loss: 0.1336 - classes_loss: 0.0548 - p_accuracy: 1.0000 - coord_IoU: 0.7951 - classes_accuracy: 0.9984 - val_loss: 1.7419 - val_p_loss: 2.0025e-05 - val_coord_loss: 0.9377 - val_classes_loss: 0.4021 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5997 - val_classes_accuracy: 0.6681
# Epoch 13/30
# 80/80 [==============================] - 14s 172ms/step - loss: 0.1999 - p_loss: 1.7084e-05 - coord_loss: 0.1128 - classes_loss: 0.0435 - p_accuracy: 1.0000 - coord_IoU: 0.8102 - classes_accuracy: 0.9981 - val_loss: 1.8014 - val_p_loss: 8.5062e-06 - val_coord_loss: 0.9845 - val_classes_loss: 0.4084 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5830 - val_classes_accuracy: 0.6903
# Epoch 14/30
# 80/80 [==============================] - 14s 173ms/step - loss: 0.1834 - p_loss: 1.5873e-05 - coord_loss: 0.1123 - classes_loss: 0.0355 - p_accuracy: 1.0000 - coord_IoU: 0.8086 - classes_accuracy: 0.9987 - val_loss: 1.7972 - val_p_loss: 9.4159e-06 - val_coord_loss: 0.9823 - val_classes_loss: 0.4074 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5940 - val_classes_accuracy: 0.6947
# Epoch 15/30
# 80/80 [==============================] - 14s 173ms/step - loss: 0.1684 - p_loss: 1.5182e-05 - coord_loss: 0.1062 - classes_loss: 0.0311 - p_accuracy: 1.0000 - coord_IoU: 0.8235 - classes_accuracy: 1.0000 - val_loss: 1.8109 - val_p_loss: 4.8266e-06 - val_coord_loss: 0.9949 - val_classes_loss: 0.4080 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6042 - val_classes_accuracy: 0.6814
# Epoch 16/30
# 80/80 [==============================] - 14s 173ms/step - loss: 0.1484 - p_loss: 1.1973e-05 - coord_loss: 0.0997 - classes_loss: 0.0244 - p_accuracy: 1.0000 - coord_IoU: 0.8225 - classes_accuracy: 1.0000 - val_loss: 1.8967 - val_p_loss: 2.2858e-06 - val_coord_loss: 0.9857 - val_classes_loss: 0.4555 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6034 - val_classes_accuracy: 0.6814
# Epoch 17/30
# 80/80 [==============================] - 14s 174ms/step - loss: 0.1572 - p_loss: 1.0520e-05 - coord_loss: 0.1062 - classes_loss: 0.0255 - p_accuracy: 1.0000 - coord_IoU: 0.8116 - classes_accuracy: 1.0000 - val_loss: 1.8356 - val_p_loss: 4.9151e-06 - val_coord_loss: 1.0049 - val_classes_loss: 0.4154 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5855 - val_classes_accuracy: 0.7080
# Epoch 18/30
# 80/80 [==============================] - 14s 175ms/step - loss: 0.1503 - p_loss: 1.0280e-05 - coord_loss: 0.1086 - classes_loss: 0.0208 - p_accuracy: 1.0000 - coord_IoU: 0.8166 - classes_accuracy: 1.0000 - val_loss: 1.7524 - val_p_loss: 9.9762e-06 - val_coord_loss: 0.9412 - val_classes_loss: 0.4056 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6006 - val_classes_accuracy: 0.7124
# Epoch 19/30
# 80/80 [==============================] - 14s 175ms/step - loss: 0.1419 - p_loss: 1.1806e-05 - coord_loss: 0.1041 - classes_loss: 0.0189 - p_accuracy: 1.0000 - coord_IoU: 0.8263 - classes_accuracy: 1.0000 - val_loss: 1.8111 - val_p_loss: 9.5818e-06 - val_coord_loss: 0.9578 - val_classes_loss: 0.4267 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5964 - val_classes_accuracy: 0.7080
# Epoch 20/30
# 80/80 [==============================] - 14s 175ms/step - loss: 0.1305 - p_loss: 8.8058e-06 - coord_loss: 0.0924 - classes_loss: 0.0190 - p_accuracy: 1.0000 - coord_IoU: 0.8293 - classes_accuracy: 0.9999 - val_loss: 1.8402 - val_p_loss: 2.8527e-05 - val_coord_loss: 0.9518 - val_classes_loss: 0.4442 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6107 - val_classes_accuracy: 0.6726
# Epoch 21/30
# 80/80 [==============================] - 14s 175ms/step - loss: 0.1330 - p_loss: 1.1886e-05 - coord_loss: 0.0984 - classes_loss: 0.0173 - p_accuracy: 1.0000 - coord_IoU: 0.8264 - classes_accuracy: 1.0000 - val_loss: 1.7868 - val_p_loss: 7.3795e-06 - val_coord_loss: 0.9362 - val_classes_loss: 0.4253 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5961 - val_classes_accuracy: 0.7035
# Epoch 22/30
# 80/80 [==============================] - 14s 175ms/step - loss: 0.1200 - p_loss: 1.1640e-05 - coord_loss: 0.0895 - classes_loss: 0.0152 - p_accuracy: 1.0000 - coord_IoU: 0.8257 - classes_accuracy: 1.0000 - val_loss: 1.8769 - val_p_loss: 7.6226e-06 - val_coord_loss: 0.9948 - val_classes_loss: 0.4411 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5854 - val_classes_accuracy: 0.6991
# Epoch 23/30
# 80/80 [==============================] - 14s 175ms/step - loss: 0.1370 - p_loss: 7.0163e-06 - coord_loss: 0.1069 - classes_loss: 0.0150 - p_accuracy: 1.0000 - coord_IoU: 0.8107 - classes_accuracy: 1.0000 - val_loss: 1.8198 - val_p_loss: 3.4095e-05 - val_coord_loss: 0.9416 - val_classes_loss: 0.4391 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5819 - val_classes_accuracy: 0.6903
# Epoch 24/30
# 80/80 [==============================] - 14s 175ms/step - loss: 0.1453 - p_loss: 1.6046e-05 - coord_loss: 0.1171 - classes_loss: 0.0141 - p_accuracy: 1.0000 - coord_IoU: 0.8024 - classes_accuracy: 1.0000 - val_loss: 1.8866 - val_p_loss: 2.1638e-05 - val_coord_loss: 0.9912 - val_classes_loss: 0.4477 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6054 - val_classes_accuracy: 0.6903
# Epoch 25/30
# 80/80 [==============================] - 14s 176ms/step - loss: 0.1241 - p_loss: 1.5444e-05 - coord_loss: 0.0964 - classes_loss: 0.0138 - p_accuracy: 1.0000 - coord_IoU: 0.8206 - classes_accuracy: 1.0000 - val_loss: 1.7941 - val_p_loss: 2.4527e-05 - val_coord_loss: 0.9172 - val_classes_loss: 0.4385 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6144 - val_classes_accuracy: 0.6549
# Epoch 26/30
# 80/80 [==============================] - 14s 176ms/step - loss: 0.0976 - p_loss: 1.2309e-05 - coord_loss: 0.0744 - classes_loss: 0.0116 - p_accuracy: 1.0000 - coord_IoU: 0.8452 - classes_accuracy: 1.0000 - val_loss: 1.7457 - val_p_loss: 9.6922e-05 - val_coord_loss: 0.9075 - val_classes_loss: 0.4190 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6109 - val_classes_accuracy: 0.7389
# Epoch 27/30
# 80/80 [==============================] - 14s 176ms/step - loss: 0.0951 - p_loss: 1.1315e-05 - coord_loss: 0.0724 - classes_loss: 0.0113 - p_accuracy: 1.0000 - coord_IoU: 0.8424 - classes_accuracy: 1.0000 - val_loss: 1.7912 - val_p_loss: 7.2098e-06 - val_coord_loss: 0.9033 - val_classes_loss: 0.4440 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6107 - val_classes_accuracy: 0.7124
# Epoch 28/30
# 80/80 [==============================] - 14s 176ms/step - loss: 0.0787 - p_loss: 1.0010e-05 - coord_loss: 0.0605 - classes_loss: 0.0091 - p_accuracy: 1.0000 - coord_IoU: 0.8542 - classes_accuracy: 1.0000 - val_loss: 1.7536 - val_p_loss: 2.2185e-05 - val_coord_loss: 0.9100 - val_classes_loss: 0.4218 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6221 - val_classes_accuracy: 0.7522
# Epoch 29/30
# 80/80 [==============================] - 14s 176ms/step - loss: 0.0758 - p_loss: 7.5083e-06 - coord_loss: 0.0599 - classes_loss: 0.0079 - p_accuracy: 1.0000 - coord_IoU: 0.8508 - classes_accuracy: 1.0000 - val_loss: 1.7927 - val_p_loss: 2.8139e-05 - val_coord_loss: 0.9111 - val_classes_loss: 0.4408 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6077 - val_classes_accuracy: 0.7035
# Epoch 30/30
# 80/80 [==============================] - 14s 176ms/step - loss: 0.0733 - p_loss: 6.5006e-06 - coord_loss: 0.0574 - classes_loss: 0.0079 - p_accuracy: 1.0000 - coord_IoU: 0.8553 - classes_accuracy: 1.0000 - val_loss: 1.8126 - val_p_loss: 2.6642e-05 - val_coord_loss: 0.9174 - val_classes_loss: 0.4476 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5984 - val_classes_accuracy: 0.7080

# %%
# Analyse des résultats : courbes d'évolution de la fonction de perte, et de l'IoU des boîtes englobantes ainsi que de l'accuracy des classes prédites
plot_training_analysis(history, metric='loss')
plot_training_analysis(history, metric='coord_IoU')
plot_training_analysis(history, metric='classes_accuracy')

# Prédiction des données de validation
y_pred_presence, y_pred_coords, y_pred_classes = model.predict(x_val)
y_pred = np.zeros(y_val.shape)
for i in range(y_pred.shape[0]):
  y_pred[i, 0] = y_pred_presence[i]
  y_pred[i, 1:5] = y_pred_coords[i]
  y_pred[i, 5:9] = y_pred_classes[i]

# Affichage des résultats sur plusieurs images
print_data_localisation(x_val, y_val, y_pred = y_pred, id=2, image_size=IMAGE_SIZE)
print_data_localisation(x_val, y_val, y_pred = y_pred, id=3, image_size=IMAGE_SIZE)
print_data_localisation(x_val, y_val, y_pred = y_pred, id=7, image_size=IMAGE_SIZE)
print_data_localisation(x_val, y_val, y_pred = y_pred, id=25, image_size=IMAGE_SIZE)
print_data_localisation(x_val, y_val, y_pred = y_pred, id=16, image_size=IMAGE_SIZE)
print_data_localisation(x_val, y_val, y_pred = y_pred, id=18, image_size=IMAGE_SIZE)
print_data_localisation(x_val, y_val, y_pred = y_pred, id=24, image_size=IMAGE_SIZE)
print_data_localisation(x_val, y_val, y_pred = y_pred, id=15, image_size=IMAGE_SIZE)

# %% [markdown]
# **On constate qu'il y a du sur-apprentissage**
#
# **Nous avons essayé de changer le poid sur les sorties. On remarque qu'augmenter le poid de la détection de classe augmente la class_accuracy**

# %% [markdown]
# En pratique, il est délicat de trouver une bonne combinaison des fonctions de perte tel que vous l'avez fait sur les cellules précédentes. L'entropie croisée et l'erreur quadratique moyenne donnent des valeurs trop différentes pour être combinables efficacement.
#
# Une variante, mais qui tend à mieux fonctionner, est d'utiliser uniquement l'erreur quadratique moyenne comme perte pour toutes les sorties.
# Testez cette solution ci-dessous ; inutile de favoriser une perte par rapport à une autre ici, vous pouvez mettre le même poids pour toutes les pertes dans la variable *loss_weights*.

# %%
from keras.optimizers import Adam

import tensorflow as tf

batch_size=16
model = create_model_localisation()
opt = Adam(learning_rate=3e-4)  

loss = [tf.keras.losses.MeanSquaredError() ,tf.keras.losses.MeanSquaredError(), tf.keras.losses.MeanSquaredError()]
metrics =[ ['accuracy'], [iou()], ['accuracy']]
loss_weights = [1, 1, 1]

model.compile(loss=loss,
              optimizer=opt,
              metrics=metrics,
              loss_weights=loss_weights
              )
history = model.fit(x_train, [y_train[:,0], y_train[:,1:5], y_train[:,5:9]],
              epochs=30,
              batch_size=batch_size,            
              validation_data=(x_val, [y_val[:,0], y_val[:,1:5], y_val[:,5:9]]))
# Out:
# Epoch 1/30
# 80/80 [==============================] - 15s 179ms/step - loss: 1.7857 - p_loss: 0.0167 - coord_loss: 1.5697 - classes_loss: 0.1993 - p_accuracy: 0.9739 - coord_IoU: 0.5198 - classes_accuracy: 0.3407 - val_loss: 1.3089 - val_p_loss: 9.2886e-05 - val_coord_loss: 1.0818 - val_classes_loss: 0.2270 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5609 - val_classes_accuracy: 0.2301
# Epoch 2/30
# 80/80 [==============================] - 14s 176ms/step - loss: 0.8557 - p_loss: 3.4708e-06 - coord_loss: 0.7180 - classes_loss: 0.1376 - p_accuracy: 1.0000 - coord_IoU: 0.6277 - classes_accuracy: 0.5869 - val_loss: 1.4708 - val_p_loss: 3.5710e-05 - val_coord_loss: 1.2432 - val_classes_loss: 0.2275 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.4938 - val_classes_accuracy: 0.3142
# Epoch 3/30
# 80/80 [==============================] - 14s 176ms/step - loss: 0.6736 - p_loss: 1.5371e-06 - coord_loss: 0.5490 - classes_loss: 0.1246 - p_accuracy: 1.0000 - coord_IoU: 0.6533 - classes_accuracy: 0.6217 - val_loss: 1.2139 - val_p_loss: 1.5922e-05 - val_coord_loss: 0.9315 - val_classes_loss: 0.2823 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5882 - val_classes_accuracy: 0.2301
# Epoch 4/30
# 80/80 [==============================] - 14s 177ms/step - loss: 0.5561 - p_loss: 1.9779e-06 - coord_loss: 0.4568 - classes_loss: 0.0993 - p_accuracy: 1.0000 - coord_IoU: 0.6857 - classes_accuracy: 0.7175 - val_loss: 1.1589 - val_p_loss: 2.5611e-05 - val_coord_loss: 0.9438 - val_classes_loss: 0.2151 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5690 - val_classes_accuracy: 0.3584
# Epoch 5/30
# 80/80 [==============================] - 14s 176ms/step - loss: 0.4010 - p_loss: 8.9225e-07 - coord_loss: 0.3162 - classes_loss: 0.0848 - p_accuracy: 1.0000 - coord_IoU: 0.7119 - classes_accuracy: 0.7541 - val_loss: 1.0112 - val_p_loss: 1.6787e-05 - val_coord_loss: 0.8426 - val_classes_loss: 0.1685 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6028 - val_classes_accuracy: 0.4469
# Epoch 6/30
# 80/80 [==============================] - 14s 176ms/step - loss: 0.3369 - p_loss: 2.2803e-06 - coord_loss: 0.2694 - classes_loss: 0.0675 - p_accuracy: 1.0000 - coord_IoU: 0.7286 - classes_accuracy: 0.8331 - val_loss: 0.9159 - val_p_loss: 5.1450e-06 - val_coord_loss: 0.7585 - val_classes_loss: 0.1574 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6362 - val_classes_accuracy: 0.5265
# Epoch 7/30
# 80/80 [==============================] - 14s 176ms/step - loss: 0.2601 - p_loss: 2.4519e-06 - coord_loss: 0.2043 - classes_loss: 0.0558 - p_accuracy: 1.0000 - coord_IoU: 0.7560 - classes_accuracy: 0.8621 - val_loss: 0.9382 - val_p_loss: 4.6594e-06 - val_coord_loss: 0.8075 - val_classes_loss: 0.1308 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6429 - val_classes_accuracy: 0.5929
# Epoch 8/30
# 80/80 [==============================] - 14s 175ms/step - loss: 0.2035 - p_loss: 2.8173e-06 - coord_loss: 0.1596 - classes_loss: 0.0440 - p_accuracy: 1.0000 - coord_IoU: 0.7767 - classes_accuracy: 0.9114 - val_loss: 0.9099 - val_p_loss: 5.2283e-06 - val_coord_loss: 0.7683 - val_classes_loss: 0.1416 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6497 - val_classes_accuracy: 0.5619
# Epoch 9/30
# 80/80 [==============================] - 14s 176ms/step - loss: 0.1584 - p_loss: 3.1463e-06 - coord_loss: 0.1161 - classes_loss: 0.0422 - p_accuracy: 1.0000 - coord_IoU: 0.7996 - classes_accuracy: 0.8964 - val_loss: 0.9457 - val_p_loss: 6.3155e-06 - val_coord_loss: 0.8158 - val_classes_loss: 0.1300 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6361 - val_classes_accuracy: 0.6239
# Epoch 10/30
# 80/80 [==============================] - 14s 175ms/step - loss: 0.1386 - p_loss: 2.8746e-06 - coord_loss: 0.1097 - classes_loss: 0.0289 - p_accuracy: 1.0000 - coord_IoU: 0.8046 - classes_accuracy: 0.9437 - val_loss: 0.9273 - val_p_loss: 4.6475e-06 - val_coord_loss: 0.7909 - val_classes_loss: 0.1364 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6385 - val_classes_accuracy: 0.5973
# Epoch 11/30
# 80/80 [==============================] - 14s 176ms/step - loss: 0.1141 - p_loss: 2.3693e-06 - coord_loss: 0.0917 - classes_loss: 0.0224 - p_accuracy: 1.0000 - coord_IoU: 0.8147 - classes_accuracy: 0.9661 - val_loss: 0.9422 - val_p_loss: 2.5205e-06 - val_coord_loss: 0.8128 - val_classes_loss: 0.1295 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6170 - val_classes_accuracy: 0.6150
# Epoch 12/30
# 80/80 [==============================] - 14s 175ms/step - loss: 0.0902 - p_loss: 1.7303e-06 - coord_loss: 0.0731 - classes_loss: 0.0171 - p_accuracy: 1.0000 - coord_IoU: 0.8388 - classes_accuracy: 0.9770 - val_loss: 0.9302 - val_p_loss: 8.8021e-06 - val_coord_loss: 0.8025 - val_classes_loss: 0.1276 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6281 - val_classes_accuracy: 0.6195
# Epoch 13/30
# 80/80 [==============================] - 14s 176ms/step - loss: 0.0756 - p_loss: 3.6038e-06 - coord_loss: 0.0613 - classes_loss: 0.0144 - p_accuracy: 1.0000 - coord_IoU: 0.8551 - classes_accuracy: 0.9842 - val_loss: 0.9156 - val_p_loss: 6.2112e-07 - val_coord_loss: 0.7913 - val_classes_loss: 0.1244 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6371 - val_classes_accuracy: 0.6593
# Epoch 14/30
# 80/80 [==============================] - 14s 176ms/step - loss: 0.0736 - p_loss: 1.1365e-06 - coord_loss: 0.0611 - classes_loss: 0.0126 - p_accuracy: 1.0000 - coord_IoU: 0.8498 - classes_accuracy: 0.9821 - val_loss: 0.9261 - val_p_loss: 1.6541e-06 - val_coord_loss: 0.7958 - val_classes_loss: 0.1303 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6363 - val_classes_accuracy: 0.6327
# Epoch 15/30
# 80/80 [==============================] - 14s 176ms/step - loss: 0.0684 - p_loss: 1.2840e-06 - coord_loss: 0.0570 - classes_loss: 0.0114 - p_accuracy: 1.0000 - coord_IoU: 0.8583 - classes_accuracy: 0.9865 - val_loss: 0.9233 - val_p_loss: 1.0843e-05 - val_coord_loss: 0.7960 - val_classes_loss: 0.1273 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6390 - val_classes_accuracy: 0.6239
# Epoch 16/30
# 80/80 [==============================] - 14s 176ms/step - loss: 0.0632 - p_loss: 1.4353e-06 - coord_loss: 0.0525 - classes_loss: 0.0108 - p_accuracy: 1.0000 - coord_IoU: 0.8632 - classes_accuracy: 0.9811 - val_loss: 0.9559 - val_p_loss: 1.8779e-06 - val_coord_loss: 0.8194 - val_classes_loss: 0.1365 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6213 - val_classes_accuracy: 0.6283
# Epoch 17/30
# 80/80 [==============================] - 14s 176ms/step - loss: 0.0560 - p_loss: 2.1874e-06 - coord_loss: 0.0489 - classes_loss: 0.0071 - p_accuracy: 1.0000 - coord_IoU: 0.8658 - classes_accuracy: 0.9934 - val_loss: 0.9133 - val_p_loss: 2.8094e-06 - val_coord_loss: 0.7890 - val_classes_loss: 0.1244 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6421 - val_classes_accuracy: 0.6637
# Epoch 18/30
# 80/80 [==============================] - 14s 176ms/step - loss: 0.0577 - p_loss: 1.1009e-06 - coord_loss: 0.0497 - classes_loss: 0.0080 - p_accuracy: 1.0000 - coord_IoU: 0.8606 - classes_accuracy: 0.9920 - val_loss: 0.9343 - val_p_loss: 6.2561e-06 - val_coord_loss: 0.7998 - val_classes_loss: 0.1344 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6331 - val_classes_accuracy: 0.6239
# Epoch 19/30
# 80/80 [==============================] - 14s 176ms/step - loss: 0.0588 - p_loss: 1.5901e-06 - coord_loss: 0.0522 - classes_loss: 0.0067 - p_accuracy: 1.0000 - coord_IoU: 0.8676 - classes_accuracy: 0.9932 - val_loss: 0.9200 - val_p_loss: 1.6961e-06 - val_coord_loss: 0.7917 - val_classes_loss: 0.1283 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6366 - val_classes_accuracy: 0.6372
# Epoch 20/30
# 80/80 [==============================] - 14s 177ms/step - loss: 0.0592 - p_loss: 1.2112e-06 - coord_loss: 0.0523 - classes_loss: 0.0069 - p_accuracy: 1.0000 - coord_IoU: 0.8571 - classes_accuracy: 0.9906 - val_loss: 0.9232 - val_p_loss: 9.8610e-07 - val_coord_loss: 0.7905 - val_classes_loss: 0.1327 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6359 - val_classes_accuracy: 0.6150
# Epoch 21/30
# 80/80 [==============================] - 14s 177ms/step - loss: 0.0678 - p_loss: 1.4290e-06 - coord_loss: 0.0620 - classes_loss: 0.0058 - p_accuracy: 1.0000 - coord_IoU: 0.8409 - classes_accuracy: 0.9931 - val_loss: 0.8915 - val_p_loss: 1.1348e-05 - val_coord_loss: 0.7633 - val_classes_loss: 0.1282 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6491 - val_classes_accuracy: 0.6504
# Epoch 22/30
# 80/80 [==============================] - 14s 176ms/step - loss: 0.0557 - p_loss: 1.7128e-06 - coord_loss: 0.0503 - classes_loss: 0.0054 - p_accuracy: 1.0000 - coord_IoU: 0.8646 - classes_accuracy: 0.9956 - val_loss: 0.9077 - val_p_loss: 9.4283e-06 - val_coord_loss: 0.7804 - val_classes_loss: 0.1273 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6324 - val_classes_accuracy: 0.6504
# Epoch 23/30
# 80/80 [==============================] - 14s 176ms/step - loss: 0.0476 - p_loss: 8.8820e-07 - coord_loss: 0.0427 - classes_loss: 0.0049 - p_accuracy: 1.0000 - coord_IoU: 0.8710 - classes_accuracy: 0.9948 - val_loss: 0.9206 - val_p_loss: 4.0304e-06 - val_coord_loss: 0.7895 - val_classes_loss: 0.1311 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6427 - val_classes_accuracy: 0.6283
# Epoch 24/30
# 80/80 [==============================] - 14s 177ms/step - loss: 0.0537 - p_loss: 8.8951e-07 - coord_loss: 0.0473 - classes_loss: 0.0064 - p_accuracy: 1.0000 - coord_IoU: 0.8695 - classes_accuracy: 0.9891 - val_loss: 0.9407 - val_p_loss: 1.8262e-06 - val_coord_loss: 0.8005 - val_classes_loss: 0.1402 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6306 - val_classes_accuracy: 0.6018
# Epoch 25/30
# 80/80 [==============================] - 14s 176ms/step - loss: 0.0490 - p_loss: 1.5029e-06 - coord_loss: 0.0443 - classes_loss: 0.0047 - p_accuracy: 1.0000 - coord_IoU: 0.8746 - classes_accuracy: 0.9941 - val_loss: 0.9399 - val_p_loss: 3.1365e-06 - val_coord_loss: 0.7962 - val_classes_loss: 0.1436 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6367 - val_classes_accuracy: 0.6018
# Epoch 26/30
# 80/80 [==============================] - 14s 176ms/step - loss: 0.0447 - p_loss: 1.2548e-06 - coord_loss: 0.0402 - classes_loss: 0.0045 - p_accuracy: 1.0000 - coord_IoU: 0.8770 - classes_accuracy: 0.9940 - val_loss: 0.8955 - val_p_loss: 1.2477e-06 - val_coord_loss: 0.7610 - val_classes_loss: 0.1345 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6427 - val_classes_accuracy: 0.6106
# Epoch 27/30
# 80/80 [==============================] - 14s 176ms/step - loss: 0.0386 - p_loss: 1.0695e-06 - coord_loss: 0.0358 - classes_loss: 0.0028 - p_accuracy: 1.0000 - coord_IoU: 0.8825 - classes_accuracy: 0.9980 - val_loss: 0.8911 - val_p_loss: 5.4047e-06 - val_coord_loss: 0.7592 - val_classes_loss: 0.1319 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6420 - val_classes_accuracy: 0.6018
# Epoch 28/30
# 80/80 [==============================] - 14s 176ms/step - loss: 0.0438 - p_loss: 1.3029e-06 - coord_loss: 0.0398 - classes_loss: 0.0040 - p_accuracy: 1.0000 - coord_IoU: 0.8764 - classes_accuracy: 0.9971 - val_loss: 0.9228 - val_p_loss: 1.9475e-06 - val_coord_loss: 0.7863 - val_classes_loss: 0.1364 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6412 - val_classes_accuracy: 0.6195
# Epoch 29/30
# 80/80 [==============================] - 14s 176ms/step - loss: 0.0508 - p_loss: 1.0967e-06 - coord_loss: 0.0462 - classes_loss: 0.0047 - p_accuracy: 1.0000 - coord_IoU: 0.8673 - classes_accuracy: 0.9929 - val_loss: 0.9119 - val_p_loss: 3.4252e-06 - val_coord_loss: 0.7770 - val_classes_loss: 0.1349 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6454 - val_classes_accuracy: 0.6018
# Epoch 30/30
# 80/80 [==============================] - 14s 176ms/step - loss: 0.0543 - p_loss: 1.1785e-06 - coord_loss: 0.0509 - classes_loss: 0.0034 - p_accuracy: 1.0000 - coord_IoU: 0.8646 - classes_accuracy: 0.9977 - val_loss: 0.9112 - val_p_loss: 1.9230e-06 - val_coord_loss: 0.7748 - val_classes_loss: 0.1364 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6463 - val_classes_accuracy: 0.6106

# %%
# Analyse des résultats : courbes d'évolution de la fonction de perte, et de l'IoU des boîtes englobantes ainsi que de l'accuracy des classes prédites
plot_training_analysis(history, metric='loss')
plot_training_analysis(history, metric='coord_IoU')
plot_training_analysis(history, metric='classes_accuracy')

# Prédiction des données de validation
y_pred_presence, y_pred_coords, y_pred_classes = model.predict(x_val)
y_pred = np.zeros(y_val.shape)
for i in range(y_pred.shape[0]):
  y_pred[i, 0] = y_pred_presence[i]
  y_pred[i, 1:5] = y_pred_coords[i]
  y_pred[i, 5:9] = y_pred_classes[i]

print_data_localisation(x_val, y_val, y_pred = y_pred, id=2, image_size=IMAGE_SIZE)
print_data_localisation(x_val, y_val, y_pred = y_pred, id=3, image_size=IMAGE_SIZE)
print_data_localisation(x_val, y_val, y_pred = y_pred, id=7, image_size=IMAGE_SIZE)
print_data_localisation(x_val, y_val, y_pred = y_pred, id=25, image_size=IMAGE_SIZE)
print_data_localisation(x_val, y_val, y_pred = y_pred, id=16, image_size=IMAGE_SIZE)
print_data_localisation(x_val, y_val, y_pred = y_pred, id=18, image_size=IMAGE_SIZE)
print_data_localisation(x_val, y_val, y_pred = y_pred, id=24, image_size=IMAGE_SIZE)
print_data_localisation(x_val, y_val, y_pred = y_pred, id=15, image_size=IMAGE_SIZE)

# %% [markdown]
# **Changer le poid des classes modifie les accuracies, mais ne résoud pas le problème de sur-apprentisage**

# %% [markdown]
# Compte-tenu de la taille réduite de la base de données, les résultats ne sont pas mal du tout ! On observe quelques confusions entre certaines classes mais les prédictions sont souvent intéressantes.
#
# Il devrait cependant subsister un fort surapprentissage à ce stade. Comme nous l'avons vu dans de précédents TPs, vous avez plusieurs possibilités qui s'offrent à vous pour le corriger :
#
#
# *   Régularisation par *weight decay* (utilisation de *kernel_regularizer* sur les couches de votre réseau)
# *   Augmentation de la base de données. Vous pouvez pour cela vous appuyer sur l'exemple fourni en TP précédent, avec une classe *Sequence* et l'utilisation de la librairie *Albumentation*.
# *   Utilisation de *transfer learning* : partant d'un réseau entraîné sur ImageNet (qui contient de nombreuses classes d'animaux), vous bénéficieriez de filtres très généraux qui aiderait à limiter le surapprentissage.

# %% [markdown]
# # Détection d'objet : version simplifiée de YOLO
#
# <center> <img src="https://drive.google.com/uc?id=1V4aAS7K_Akj83apuMZ2vRjNvjgdgoOCh" width=500></center>
# <caption><center> Figure 5: Pipeline de l'algorithme YOLO ([Redmon 2016]) </center></caption>
#
# Dans cette partie, nous allons tenter d'aller plus loin et d'implémenter une version simplifiée de YOLO. Cette version est considérée simplifiée car ne reprenant pas l'intégralité des éléments décrite dans l'article de Redmon (par exemple, sur le choix de l'optimiseur).
#
# Pour rappel, l'idée de YOLO est de découper l'image en une grille de cellules et de réaliser une prédiction de plusieurs boîtes englobantes ainsi qu'une classification par cellule.
#
# Dans la suite, et par souci de simplicité, nous ne considérerons qu'une boîte englobante par cellule.

# %% [markdown]
# ## Préparation des données

# %%
IMAGE_SIZE = 64
CELL_PER_DIM = 8
BOX_PER_CELL = 1
NB_CLASSES = 4
PIX_PER_CELL = IMAGE_SIZE/CELL_PER_DIM

DATASET_SIZE = 376*4

# %% [markdown]
# Chargement des données et mise en forme pour le problème de détection. Les données qui posent problème (plus d'une boîte englobante par cellule) sont indiquées et affichées pendant le chargement.

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
# %matplotlib inline

import PIL
from PIL import Image
import os, sys

import keras
from keras.utils import np_utils

def load_data_detection():
  # Chemin vers la base de données
  ds_path = "/content/wildlife/"
  # Chemins vers les données des 4 différentes classes
  paths = [ds_path+"buffalo/", ds_path+"elephant/", ds_path+"rhino/", ds_path+"zebra/"]
  # Indice d'ajout de données dans les variables x et y 
  i = 0
  # Préparation des structures de données pour x et y
  x = np.zeros((DATASET_SIZE, IMAGE_SIZE, IMAGE_SIZE, 3))
  y = np.zeros((DATASET_SIZE, CELL_PER_DIM, CELL_PER_DIM, NB_CLASSES + 5*BOX_PER_CELL))

  # Parcours des chemins de chacune des classes
  for path in paths:

    # Parcours des fichiers (classés) du répertoire
    dirs = os.listdir(path)
    dirs.sort()

    for item in dirs:
      if os.path.isfile(path + item):
        # Extraction de l'extension du fichier 
        extension = item.split(".")[1]

        if extension=="jpg" or extension=="JPG":
          # Image : on va remplir la variable x
          # Lecture de l'image
          img = Image.open(path + item)
          #f, e = os.path.splitext(path+item)

          # Mise à l'échelle de l'image
          img = img.resize((IMAGE_SIZE, IMAGE_SIZE), Image.ANTIALIAS)
          # Remplissage de la variable x
          x[i] = np.asarray(img, dtype=np.int32)

        elif extension=="txt":
          # Texte : coordonnées de boîtes englobantes pour remplir y
          labels = open(path + item, "r")
          # Récupération des lignes du fichier texte
          labels = labels.read().split('\n')
          # Si la dernière ligne est vide, la supprimer 
          if labels[-1]=="":
            del labels[-1]

          err_flag = 0
          boxes = []
          for label in labels:
            # Récupération des informations de la boîte englobante
            label = label.split()
            # Coordonnées du centre de la boîte englobante dans le repère image
            cx, cy = float(label[1]) * IMAGE_SIZE, float(label[2]) * IMAGE_SIZE
            # Détermination des indices de la cellule dans laquelle tombe le centre
            ind_x, ind_y = int(cx // PIX_PER_CELL), int(cy // PIX_PER_CELL)
            # YOLO : "The (x, y) coordinates represent the center of the box relative to the bounds of the grid cell."
            # On va donc calculer les coordonnées du centre relativement à la cellule dans laquelle il se situe
            cx_cell = (cx - ind_x * PIX_PER_CELL) / PIX_PER_CELL
            cy_cell = (cy - ind_y * PIX_PER_CELL) / PIX_PER_CELL
            # Indice de confiance de la boîte englobante
            presence = np.array([1], dtype="i")
            # "One-hot vector" représentant les probabilités de classe dans la cellule
            classes = np_utils.to_categorical(label[0], num_classes=4)
            # On range les probabilités de classe à la fin du vecteur ([ BOX 1 ; BOX 2 ; ... ; BOX N ; CLASSES])
            y[i, ind_x, ind_y, 5 * BOX_PER_CELL:] = classes

            boxes.append([cx, cy, label[3]*IMAGE_SIZE, label[4]*IMAGE_SIZE])
            # Détermination de l'indice de la boîte englobante de cellule dans laquelle ranger les informations
            ind_box = 0
            while y[i, ind_x, ind_y, 5*ind_box] == 1 and ind_box < BOX_PER_CELL - 1:
              # Si la boîte d'indice courant est déjà utilisée (présence = 1) 
              # et que l'on a pas atteint le nombre maximal de boîtes, on passe à la boîte suivante
              ind_box = ind_box + 1

            if y[i, ind_x, ind_y, 5*ind_box] == 1:
              print("ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES")
              print(path + item)
              err_flag = 1
            else:
              y[i, ind_x, ind_y, 5*ind_box] = 1
              y[i, ind_x, ind_y, 5*ind_box + 1] = cx_cell
              y[i, ind_x, ind_y, 5*ind_box + 2] = cy_cell
              # Largeur et hauteur de boîte
              y[i, ind_x, ind_y, 5*ind_box + 3] = math.sqrt(float(label[3]))
              y[i, ind_x, ind_y, 5*ind_box + 4] = math.sqrt(float(label[4]))

          i = i + 1
          if err_flag == 1:
            img_name = item.split(".")[0]
            img = Image.open(path + img_name + '.jpg')
            # Mise à l'échelle de l'image
            img = img.resize((IMAGE_SIZE, IMAGE_SIZE), Image.ANTIALIAS)

            plt.imshow(img)
            for ind_cell in range(CELL_PER_DIM):                
              plt.plot([ind_cell*PIX_PER_CELL, ind_cell*PIX_PER_CELL], [0, IMAGE_SIZE-1], 'k-')
              plt.plot([0, IMAGE_SIZE-1], [ind_cell*PIX_PER_CELL, ind_cell*PIX_PER_CELL], 'k-')

            #for ind_y in range(CELL_PER_DIM):

            for ind_box_plot in range(len(boxes)):
              box = boxes[ind_box_plot]
              plt.plot(box[0], box[1], 'b.')
            plt.show()

        else:
          print("extension trouvée : ", extension)

  return x, y

x,y = load_data_detection()
# Out:
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/buffalo/273.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/buffalo/273.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/buffalo/273.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/buffalo/300.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/buffalo/339.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/buffalo/339.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/elephant/031.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/elephant/031.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/elephant/035.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/elephant/074.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/elephant/084.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/elephant/112.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/elephant/121.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/elephant/121.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/elephant/121.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/elephant/121.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/elephant/130.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/elephant/130.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/elephant/130.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/elephant/166.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/elephant/172.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/elephant/187.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/elephant/227.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/elephant/253.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/elephant/324.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/elephant/345.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/elephant/358.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/elephant/361.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/rhino/110.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/rhino/137.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/rhino/323.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/zebra/034.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/zebra/034.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/zebra/046.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/zebra/061.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/zebra/063.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/zebra/074.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/zebra/074.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/zebra/076.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/zebra/113.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/zebra/116.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/zebra/121.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/zebra/121.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/zebra/121.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/zebra/121.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/zebra/121.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/zebra/121.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/zebra/121.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/zebra/121.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/zebra/131.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/zebra/199.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/zebra/208.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/zebra/228.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/zebra/284.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/zebra/286.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/zebra/339.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/zebra/370.txt
# ERREUR : LA CELLULE CONTIENT DEJA TOUTES LES BOITES DISPONIBLES
# /content/wildlife/zebra/376.txt

# %%
from sklearn.model_selection import train_test_split
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.15, random_state=42)

# Normalisation des images
x_train = x_train/255
x_val = x_val/255

# %%
x_train.shape, y_train.shape, x_val.shape, y_val.shape
# Out:
# ((1278, 64, 64, 3), (1278, 8, 8, 9), (226, 64, 64, 3), (226, 8, 8, 9))

# %%
def print_data_detection(x, y, id=None, image_size=IMAGE_SIZE):
  if id==None:
    # Tirage aléatoire d'une image dans la base
    num_img = np.random.randint(x.shape[0]-1)
  else:
    num_img = id

  img = x[num_img]
  lab = y[num_img]

  colors = ["blue", "yellow", "red", "orange"] # Différentes couleurs pour les différentes classes
  classes = ["Buffalo", "Elephant", "Rhino", "Zebra"]

  boxes = lab[:, :, 1:5]
  for ind_x in range(CELL_PER_DIM):
    for ind_y in range(CELL_PER_DIM):
      box = boxes[ind_x, ind_y]
      box[0] = box[0] * PIX_PER_CELL + ind_x * PIX_PER_CELL
      box[1] = box[1] * PIX_PER_CELL + ind_y * PIX_PER_CELL
      box[2] = box[2]**2 * IMAGE_SIZE
      box[3] = box[3]**2 * IMAGE_SIZE
      boxes[ind_x, ind_y] = box

  # Récupération de toutes les informations des boîtes englobantes
  all_presences = np.reshape(lab[:, :, 0], (CELL_PER_DIM*CELL_PER_DIM))
  all_boxes = np.reshape(lab[:, :, 1:5], (-1, 4))
  all_classes = np.reshape(lab[:, :, 5:9], (-1, 4))

  # Eliminer toutes les boîtes englobantes dont la probabilité de presence est < 0.5 
  all_boxes = all_boxes[np.where(all_presences > 0.5)]
  all_classes = all_classes[np.where(all_presences > 0.5)]

  # Affichage de l'image
  plt.imshow(img)
  for i in range(all_boxes.shape[0]):

    # Détermination de la classe
    class_id = np.argmax(all_classes[i])
    lab = all_boxes[i]
    #print("x: {}, y: {}, w: {}, h:{}".format(ax,ay,width, height))
    # Détermination des extrema de la boîte englobante
    p_x = [lab[0]-lab[2]/2, lab[0]+lab[2]/2]
    p_y = [lab[1]-lab[3]/2, lab[1]+lab[3]/2]
    # Affichage de la boîte englobante, dans la bonne couleur
    plt.plot([p_x[0], p_x[0]],p_y,color=colors[class_id])
    plt.plot([p_x[1], p_x[1]],p_y,color=colors[class_id])
    plt.plot(p_x,[p_y[0],p_y[0]],color=colors[class_id])
    plt.plot(p_x,[p_y[1],p_y[1]],color=colors[class_id])
    plt.title("Vérité Terrain : Image {} - {}".format(num_img, classes[class_id]))
  
  plt.show()  


print_data_detection(x_train, y_train, image_size=IMAGE_SIZE)

# %% [markdown]
# <center> <img src="https://drive.google.com/uc?id=1_wXc_gTIAr37STaxu3chq1EEjVSKv6a5" width=500></center>
# <caption><center> Figure 6: Illustration de la couche de sortie de YOLO. </center></caption>
#
# Le modèle que je vous propose ci-dessous n'est qu'une possibilité parmi beaucoup d'autres. L'article de Redmon mentionne une instabilité délicate pendant l'entraînement, ce qui m'a encouragé à choisir une fonction d'activation *elu* (*exponential linear unit*).
#
# A vous de compléter la dernière couche pour avoir une sortie de la bonne dimension.

# %%
import keras
from keras import layers
from keras import models
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Reshape, Dropout, Input
from keras.models import Sequential
from keras import regularizers

def create_model_YOLO(input_shape=(64, 64, 3)):

  input_layer = Input(shape=input_shape)

  conv1 = Conv2D(32, 3, activation = 'elu', padding = 'same', kernel_initializer = 'he_normal', kernel_regularizer=regularizers.l1_l2(l1=0, l2=2e-4))(input_layer)
  # drop = Dropout(0.1)(conv1)
  batchnorm = BatchNormalization()(conv1)

  conv1 = Conv2D(32, 3, activation = 'elu', padding = 'same', kernel_initializer = 'he_normal', kernel_regularizer=regularizers.l1_l2(l1=0, l2=2e-4))(batchnorm)
  # drop = Dropout(0.1)(conv1)
  batchnorm = BatchNormalization()(conv1)

  conv1 = Conv2D(32, 3, activation = 'elu', padding = 'same', kernel_initializer = 'he_normal', kernel_regularizer=regularizers.l1_l2(l1=0, l2=2e-4))(batchnorm)
  # drop = Dropout(0.1)(conv1)
  batchnorm = BatchNormalization()(conv1)

  pool1 = MaxPooling2D(pool_size=(2, 2))(batchnorm)
  
  conv2 = Conv2D(64, 3, activation = 'elu', padding = 'same', kernel_initializer = 'he_normal', kernel_regularizer=regularizers.l1_l2(l1=0, l2=2e-4))(pool1)
  # drop = Dropout(0.1)(conv2)
  batchnorm = BatchNormalization()(conv2)

  conv2 = Conv2D(64, 3, activation = 'elu', padding = 'same', kernel_initializer = 'he_normal', kernel_regularizer=regularizers.l1_l2(l1=0, l2=2e-4))(batchnorm)
  # drop = Dropout(0.1)(conv2)
  batchnorm = BatchNormalization()(conv2)

  conv2 = Conv2D(64, 3, activation = 'elu', padding = 'same', kernel_initializer = 'he_normal', kernel_regularizer=regularizers.l1_l2(l1=0, l2=2e-4))(batchnorm)
  # drop = Dropout(0.2)(conv2)
  batchnorm = BatchNormalization()(conv2)

  pool2 = MaxPooling2D(pool_size=(2, 2))(batchnorm)
  
  conv3 = Conv2D(128, 3, activation = 'elu', padding = 'same', kernel_initializer = 'he_normal', kernel_regularizer=regularizers.l1_l2(l1=0, l2=2e-4))(pool2)
  # drop = Dropout(0.1)(conv3)
  batchnorm = BatchNormalization()(conv3)

  conv3 = Conv2D(128, 3, activation = 'elu', padding = 'same', kernel_initializer = 'he_normal', kernel_regularizer=regularizers.l1_l2(l1=0, l2=2e-4))(batchnorm)
  # drop = Dropout(0.1)(conv3)
  batchnorm = BatchNormalization()(conv3)

  conv3 = Conv2D(128, 3, activation = 'elu', padding = 'same', kernel_initializer = 'he_normal', kernel_regularizer=regularizers.l1_l2(l1=0, l2=2e-4))(batchnorm)
  # drop = Dropout(0.1)(conv3)
  batchnorm = BatchNormalization()(conv3)
  pool3 = MaxPooling2D(pool_size=(2, 2))(batchnorm)

  dense4 = Flatten()(pool3)
  dense4 = Dense(512, kernel_regularizer=regularizers.l2(0.002), activation='elu')(dense4)
  dense5 = Dense(512, kernel_regularizer=regularizers.l2(0.002), activation='elu')(dense4)
  output = Dense(CELL_PER_DIM*CELL_PER_DIM*(NB_CLASSES+5*BOX_PER_CELL), activation='linear')(dense5)
  output = Reshape((CELL_PER_DIM, CELL_PER_DIM, NB_CLASSES+5*BOX_PER_CELL))(output)

  model = Model(input_layer, output)

  return model

# %%
model.summary()
model = create_model_YOLO()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 64, 64, 3)]  0
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 32)   896         input_2[0][0]
# __________________________________________________________________________________________________
# norm_1 (BatchNormalization)     (None, 64, 64, 32)   128         conv2d_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 64, 64, 32)   0           norm_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 32)   0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 1024) 294912      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 1024) 4096        conv2d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 32, 32, 1024) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 1024) 9437184     leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 1024) 4096        conv2d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 32, 32, 1024) 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 1024) 9437184     leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 1024) 4096        conv2d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 32, 32, 1024) 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 9)    9225        leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 9)    36          conv2d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 32, 32, 9)    0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 9216)         0           leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# p (Dense)                       (None, 1)            9217        flatten_1[0][0]
# __________________________________________________________________________________________________
# coord (Dense)                   (None, 4)            36868       flatten_1[0][0]
# __________________________________________________________________________________________________
# classes (Dense)                 (None, 4)            36868       flatten_1[0][0]
# ==================================================================================================
# Total params: 19,274,806
# Trainable params: 19,268,580
# Non-trainable params: 6,226
# __________________________________________________________________________________________________

# %% [markdown]
# <center> <img src="https://drive.google.com/uc?id=1Fbt_Wh_BqZj8Pwt3-04325ItCkQp5G9X" style="width:500;height:300px;"></center>
# <caption><center> Figure 7: Détail de la fonction de perte définie dans l'article YOLO v1 </center></caption>
#
# Nous arrivons maintenant à la partie délicate de l'implémentation de YOLO : la définition de la fonction de coût à utiliser.
#
# Lorsque l'on écrit une fonction de coût personnalisée en Keras, il est nécessaire d'utiliser uniquement les fonctions présentes sur la page suivante :
# https://www.tensorflow.org/api_docs/python/tf/keras/backend
#
# En effet cette fonction de coût qui sera appelée pendant l'entraînement traitera des tenseurs, et non des tableau *numpy*. On doit donc utiliser la librairie Tensorflow qui permet de manipuler les tenseurs.
#
# Une partie essentielle de la fonction est déjà écrite : celle qui permet de séparer les données des cellules dites "vide" (la vérité terrain ne contient pas de boîte englobante) des "non vides".
#
# Le détail de la fonction de coût est indiqué ci-dessus : dans l'article $\lambda_{\text{coord}} = 5$ et $\lambda_{\text{noobj}} = 0.5$. Les $x_i$, $y_i$, $w_i$, $h_i$ correspondent aux coordonnées d'une boîte englobante, $C_i$ correspond à la probabilité de présence d'un objet dans la cellule, et les $p_i(c)$ sont les probabilités de classe.
#
# A vous de compléter l'expression des sous-fonctions de la fonction de coût (les fonctions *K.sum* et *K.square* devraient vous suffire !)
#
# **NB : cette implémentation de la fonction de coût est très simplifiée et prend en compte le fait qu'il n'y a qu'une seule boîte englobante par cellule.**

# %%
from keras import backend as K

# Définition de la fonction de perte YOLO
def YOLOss(lambda_coord, lambda_noobj):

    # Partie "verte" : sous-partie concernant l'indice de confiance et les 
    # probabilités de classe dans le cas où une boîte est présente dans la cellule
    def box_loss(y_true, y_pred):
      square = K.square(y_true[:, 0] - y_pred[:, 0])
      sum = K.sum(square)

      square_2 = K.square(y_true[:, 5:] - y_pred[:, 5:])
      sum_2 = K.sum(square_2)

      return (sum + sum_2)

    # Partie "bleue" : sous-partie concernant les coordonnées de boîte englobante 
    # dans le cas où une boîte est présente dans la cellule
    def coord_loss(y_true, y_pred):
      square_x = K.square(y_true[:, 1] - y_pred[:, 1])
      square_y = K.square(y_true[:, 2] - y_pred[:, 2])
      sum_xy = K.sum(square_x + square_y)

      square_w = K.square( K.sqrt(y_true[:, 3]) - K.sqrt(y_pred[:, 3]) )
      square_h = K.square( K.sqrt(y_true[:, 4]) - K.sqrt(y_pred[:, 4]) )
      sum_wh = K.sum(square_w + square_h)

      return sum_wh + sum_xy


    # Partie "rouge" : sous-partie concernant l'indice de confiance  
    # dans le cas où aucune boîte n'est présente dans la cellule
    def nobox_loss(y_true, y_pred):
      return K.sum(K.square(y_true[:, 0] - y_pred[:, 0]))


    def YOLO_loss(y_true, y_pred):

      # On commence par reshape les tenseurs de bs x S x S x (5B+C) à (bsxSxS) x (5B+C)
      y_true = K.reshape(y_true, shape=(-1, 9))
      y_pred = K.reshape(y_pred, shape=(-1, 9))

      # On cherche (dans les labels y_true) les indices des cellules pour lesquelles au moins la première boîte englobante est présente
      not_empty = K.greater_equal(y_true[:, 0], 1)      
      indices = K.arange(0, K.shape(y_true)[0])
      indices_notempty_cells = indices[not_empty]

      empty = K.less_equal(y_true[:, 0], 0)
      indices_empty_cells = indices[empty]

      # On sépare les cellules de y_true et y_pred avec ou sans boîte englobante
      y_true_notempty = K.gather(y_true, indices_notempty_cells)
      y_pred_notempty = K.gather(y_pred, indices_notempty_cells)

      y_true_empty = K.gather(y_true, indices_empty_cells)
      y_pred_empty = K.gather(y_pred, indices_empty_cells)

      return box_loss(y_true_notempty, y_pred_notempty) + lambda_coord*coord_loss(y_true_notempty, y_pred_notempty) + lambda_noobj*nobox_loss(y_true_empty, y_pred_empty)

   
    # Return a function
    return YOLO_loss

# %%
print("x train shape", np.shape(x_train))
print("y train shape", np.shape(y_train))
# Out:
# x train shape (1278, 64, 64, 3)
# y train shape (1278, 8, 8, 9)

# %% [markdown]
# **On réalise une data augmentation avec imgaug**

# %%
from imgaug import augmenters as iaa

x_train_augmented = x_train
y_train_augmented = y_train


seq = iaa.Sequential([
    iaa.Fliplr(0.5), # horizontal flips
    iaa.Crop(percent=(0, 0.05)), # random crops
    # Small gaussian blur with random sigma between 0 and 0.5.
    # But we only blur about 50% of all images.
    iaa.Sometimes(
        0.5,
        iaa.GaussianBlur(sigma=(0, 0.2))
    ),
], random_order=True) # apply augmenters in random order

nb_data = np.shape(x_train)[0]
for p in range(0, 3):
  print("data augmentation numéro : ", p)
  for i in range(0, nb_data):
    #print(i)
    image_aug = seq(images = x_train[i, ...])
    #print(np.shape())
    #print("image aug shape", np.shape(image_aug))
    #print("label shape", np.shape(y_train[i, ...]))
    #plt.imshow(image_aug)
    #print("image aug shape", np.shape(image_aug))
    #print("x train shape", np.shape(x_train))
    x_train_augmented = np.concatenate((x_train_augmented, np.array([image_aug])))
    y_train_augmented = np.concatenate((y_train_augmented, np.array([y_train[i,...]])))
# Out:
# data augmentation numéro :  0
# data augmentation numéro :  1
# data augmentation numéro :  2

# %%
print("x shape", np.shape(x_train_augmented))
plt.imshow(image_aug)
# Out:
# x shape (5112, 64, 64, 3)

# %%
from keras.optimizers import Adam

import tensorflow as tf

batch_size=16
model = create_model_YOLO()
opt = Adam(learning_rate=1e-4)  

loss=[YOLOss(5, 0.5)]

model.compile(loss=loss,
              optimizer=opt)

history = model.fit(x_train_augmented, y_train_augmented,
              epochs=300,
              batch_size=batch_size,           
              validation_data=(x_val, y_val))
# Out:
# Epoch 1/300
# 320/320 [==============================] - 7s 16ms/step - loss: 445.3732 - val_loss: 103.8044
# Epoch 2/300
# 320/320 [==============================] - 4s 14ms/step - loss: 105.4702 - val_loss: 94.8871
# Epoch 3/300
# 320/320 [==============================] - 5s 14ms/step - loss: 82.5773 - val_loss: 100.1815
# Epoch 4/300
# 320/320 [==============================] - 5s 14ms/step - loss: 124.4387 - val_loss: 90.1390
# Epoch 5/300
# 320/320 [==============================] - 5s 14ms/step - loss: 89.4046 - val_loss: 90.1748
# Epoch 6/300
# 320/320 [==============================] - 4s 14ms/step - loss: 59.8623 - val_loss: 88.8366
# Epoch 7/300
# 320/320 [==============================] - 5s 14ms/step - loss: 45.5908 - val_loss: 95.3899
# Epoch 8/300
# 320/320 [==============================] - 5s 14ms/step - loss: 44.2772 - val_loss: 88.1422
# Epoch 9/300
# 320/320 [==============================] - 5s 14ms/step - loss: 38.2140 - val_loss: 87.3829
# Epoch 10/300
# 320/320 [==============================] - 5s 14ms/step - loss: 33.4783 - val_loss: 90.1838
# Epoch 11/300
# 320/320 [==============================] - 5s 14ms/step - loss: 33.9852 - val_loss: 90.7681
# Epoch 12/300
# 320/320 [==============================] - 5s 14ms/step - loss: 31.5732 - val_loss: 85.5805
# Epoch 13/300
# 320/320 [==============================] - 5s 14ms/step - loss: 29.5198 - val_loss: 83.6697
# Epoch 14/300
# 320/320 [==============================] - 5s 14ms/step - loss: 25.7840 - val_loss: 85.7460
# Epoch 15/300
# 320/320 [==============================] - 5s 14ms/step - loss: 31.4521 - val_loss: 82.3740
# Epoch 16/300
# 320/320 [==============================] - 5s 14ms/step - loss: 32.4952 - val_loss: 80.3644
# Epoch 17/300
# 320/320 [==============================] - 5s 14ms/step - loss: 28.6803 - val_loss: 80.6591
# Epoch 18/300
# 320/320 [==============================] - 5s 15ms/step - loss: 20.4983 - val_loss: 79.4924
# Epoch 19/300
# 320/320 [==============================] - 5s 14ms/step - loss: 18.5509 - val_loss: 79.7855
# Epoch 20/300
# 320/320 [==============================] - 5s 14ms/step - loss: 25.6203 - val_loss: 80.2971
# Epoch 21/300
# 320/320 [==============================] - 5s 14ms/step - loss: 18.8163 - val_loss: 84.1324
# Epoch 22/300
# 320/320 [==============================] - 5s 14ms/step - loss: 33.6775 - val_loss: 79.1194
# Epoch 23/300
# 320/320 [==============================] - 5s 14ms/step - loss: 16.6187 - val_loss: 79.7013
# Epoch 24/300
# 320/320 [==============================] - 5s 14ms/step - loss: 24.0833 - val_loss: 78.3044
# Epoch 25/300
# 320/320 [==============================] - 5s 14ms/step - loss: 15.2506 - val_loss: 77.3812
# Epoch 26/300
# 320/320 [==============================] - 5s 14ms/step - loss: 14.4533 - val_loss: 77.6240
# Epoch 27/300
# 320/320 [==============================] - 5s 14ms/step - loss: 15.0427 - val_loss: 78.1855
# Epoch 28/300
# 320/320 [==============================] - 5s 14ms/step - loss: 16.2307 - val_loss: 80.0151
# Epoch 29/300
# 320/320 [==============================] - 5s 14ms/step - loss: 18.3199 - val_loss: 76.1725
# Epoch 30/300
# 320/320 [==============================] - 5s 14ms/step - loss: 14.5104 - val_loss: 79.6482
# Epoch 31/300
# 320/320 [==============================] - 5s 14ms/step - loss: 34.5037 - val_loss: 78.6639
# Epoch 32/300
# 320/320 [==============================] - 5s 14ms/step - loss: 17.2577 - val_loss: 75.8565
# Epoch 33/300
# 320/320 [==============================] - 5s 14ms/step - loss: 20.4725 - val_loss: 77.3726
# Epoch 34/300
# 320/320 [==============================] - 5s 14ms/step - loss: 15.8237 - val_loss: 76.4446
# Epoch 35/300
# 320/320 [==============================] - 5s 14ms/step - loss: 12.4896 - val_loss: 75.9717
# Epoch 36/300
# 320/320 [==============================] - 5s 14ms/step - loss: 14.6326 - val_loss: 74.8444
# Epoch 37/300
# 320/320 [==============================] - 5s 14ms/step - loss: 12.7892 - val_loss: 76.6633
# Epoch 38/300
# 320/320 [==============================] - 5s 14ms/step - loss: 21.3892 - val_loss: 76.5171
# Epoch 39/300
# 320/320 [==============================] - 5s 14ms/step - loss: 13.4372 - val_loss: 75.4308
# Epoch 40/300
# 320/320 [==============================] - 5s 14ms/step - loss: 10.8065 - val_loss: 75.0270
# Epoch 41/300
# 320/320 [==============================] - 5s 14ms/step - loss: 11.0646 - val_loss: 75.2665
# Epoch 42/300
# 320/320 [==============================] - 5s 14ms/step - loss: 10.8051 - val_loss: 75.0422
# Epoch 43/300
# 320/320 [==============================] - 5s 14ms/step - loss: 10.7195 - val_loss: 74.8220
# Epoch 44/300
# 320/320 [==============================] - 5s 14ms/step - loss: 11.7692 - val_loss: 76.0852
# Epoch 45/300
# 320/320 [==============================] - 5s 14ms/step - loss: 14.9328 - val_loss: 74.6479
# Epoch 46/300
# 320/320 [==============================] - 5s 14ms/step - loss: 11.6477 - val_loss: 74.3432
# Epoch 47/300
# 320/320 [==============================] - 5s 14ms/step - loss: 16.5524 - val_loss: 71.1552
# Epoch 48/300
# 320/320 [==============================] - 5s 14ms/step - loss: 8.4178 - val_loss: 71.1672
# Epoch 49/300
# 320/320 [==============================] - 5s 14ms/step - loss: 8.6142 - val_loss: 71.2357
# Epoch 50/300
# 320/320 [==============================] - 5s 15ms/step - loss: 8.1945 - val_loss: 71.2957
# Epoch 51/300
# 320/320 [==============================] - 5s 15ms/step - loss: 7.5128 - val_loss: 71.4217
# Epoch 52/300
# 320/320 [==============================] - 5s 14ms/step - loss: 8.3859 - val_loss: 71.3229
# Epoch 53/300
# 320/320 [==============================] - 5s 14ms/step - loss: 8.4325 - val_loss: 70.0894
# Epoch 54/300
# 320/320 [==============================] - 5s 15ms/step - loss: 9.0052 - val_loss: 70.3845
# Epoch 55/300
# 320/320 [==============================] - 5s 14ms/step - loss: 8.0314 - val_loss: 69.8162
# Epoch 56/300
# 320/320 [==============================] - 5s 14ms/step - loss: 9.0328 - val_loss: 70.6578
# Epoch 57/300
# 320/320 [==============================] - 5s 14ms/step - loss: 8.2364 - val_loss: 70.7475
# Epoch 58/300
# 320/320 [==============================] - 5s 14ms/step - loss: 7.4907 - val_loss: 70.1253
# Epoch 59/300
# 320/320 [==============================] - 5s 14ms/step - loss: 8.0526 - val_loss: 69.9555
# Epoch 60/300
# 320/320 [==============================] - 5s 14ms/step - loss: 7.5023 - val_loss: 69.3631
# Epoch 61/300
# 320/320 [==============================] - 5s 14ms/step - loss: 9.4142 - val_loss: 69.4697
# Epoch 62/300
# 320/320 [==============================] - 5s 14ms/step - loss: 7.3768 - val_loss: 70.3145
# Epoch 63/300
# 320/320 [==============================] - 5s 14ms/step - loss: 8.3142 - val_loss: 70.1744
# Epoch 64/300
# 320/320 [==============================] - 5s 14ms/step - loss: 6.8325 - val_loss: 70.2552
# Epoch 65/300
# 320/320 [==============================] - 5s 14ms/step - loss: 6.8949 - val_loss: 69.0017
# Epoch 66/300
# 320/320 [==============================] - 5s 14ms/step - loss: 6.7219 - val_loss: 69.5160
# Epoch 67/300
# 320/320 [==============================] - 5s 14ms/step - loss: 6.6145 - val_loss: 70.3186
# Epoch 68/300
# 320/320 [==============================] - 5s 14ms/step - loss: 7.6400 - val_loss: 69.9515
# Epoch 69/300
# 320/320 [==============================] - 5s 15ms/step - loss: 13.7469 - val_loss: 69.2549
# Epoch 70/300
# 320/320 [==============================] - 5s 15ms/step - loss: 7.0315 - val_loss: 68.5213
# Epoch 71/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.6979 - val_loss: 68.8138
# Epoch 72/300
# 320/320 [==============================] - 5s 15ms/step - loss: 6.8604 - val_loss: 69.0585
# Epoch 73/300
# 320/320 [==============================] - 5s 14ms/step - loss: 6.4546 - val_loss: 69.7461
# Epoch 74/300
# 320/320 [==============================] - 5s 15ms/step - loss: 6.3773 - val_loss: 68.6071
# Epoch 75/300
# 320/320 [==============================] - 5s 14ms/step - loss: 6.4009 - val_loss: 69.1515
# Epoch 76/300
# 320/320 [==============================] - 5s 15ms/step - loss: 6.7819 - val_loss: 68.7566
# Epoch 77/300
# 320/320 [==============================] - 5s 14ms/step - loss: 9.4389 - val_loss: 73.6845
# Epoch 78/300
# 320/320 [==============================] - 5s 14ms/step - loss: 9.1467 - val_loss: 67.6366
# Epoch 79/300
# 320/320 [==============================] - 5s 14ms/step - loss: 6.7320 - val_loss: 68.6943
# Epoch 80/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.3617 - val_loss: 67.9887
# Epoch 81/300
# 320/320 [==============================] - 5s 14ms/step - loss: 5.1166 - val_loss: 68.2054
# Epoch 82/300
# 320/320 [==============================] - 5s 14ms/step - loss: 5.2831 - val_loss: 67.6708
# Epoch 83/300
# 320/320 [==============================] - 5s 14ms/step - loss: 6.4578 - val_loss: 69.3718
# Epoch 84/300
# 320/320 [==============================] - 5s 15ms/step - loss: 6.0732 - val_loss: 68.9951
# Epoch 85/300
# 320/320 [==============================] - 5s 14ms/step - loss: 6.1238 - val_loss: 67.8511
# Epoch 86/300
# 320/320 [==============================] - 5s 15ms/step - loss: 6.9718 - val_loss: 68.8372
# Epoch 87/300
# 320/320 [==============================] - 5s 14ms/step - loss: 5.5852 - val_loss: 67.8290
# Epoch 88/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.7816 - val_loss: 68.7609
# Epoch 89/300
# 320/320 [==============================] - 5s 15ms/step - loss: 6.0893 - val_loss: 67.6762
# Epoch 90/300
# 320/320 [==============================] - 5s 14ms/step - loss: 8.4816 - val_loss: 67.3778
# Epoch 91/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.8399 - val_loss: 67.3666
# Epoch 92/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.6979 - val_loss: 67.7809
# Epoch 93/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.6733 - val_loss: 67.6333
# Epoch 94/300
# 320/320 [==============================] - 5s 14ms/step - loss: 5.1733 - val_loss: 68.0989
# Epoch 95/300
# 320/320 [==============================] - 5s 14ms/step - loss: 5.5696 - val_loss: 67.5496
# Epoch 96/300
# 320/320 [==============================] - 5s 14ms/step - loss: 5.9769 - val_loss: 67.4041
# Epoch 97/300
# 320/320 [==============================] - 5s 15ms/step - loss: 6.4716 - val_loss: 67.5349
# Epoch 98/300
# 320/320 [==============================] - 5s 15ms/step - loss: 6.5087 - val_loss: 67.4585
# Epoch 99/300
# 320/320 [==============================] - 5s 14ms/step - loss: 5.5154 - val_loss: 66.5951
# Epoch 100/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.0966 - val_loss: 67.1582
# Epoch 101/300
# 320/320 [==============================] - 5s 14ms/step - loss: 5.1429 - val_loss: 67.0119
# Epoch 102/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.0366 - val_loss: 66.9698
# Epoch 103/300
# 320/320 [==============================] - 5s 15ms/step - loss: 7.6292 - val_loss: 67.0854
# Epoch 104/300
# 320/320 [==============================] - 5s 15ms/step - loss: 6.0457 - val_loss: 67.2318
# Epoch 105/300
# 320/320 [==============================] - 5s 14ms/step - loss: 5.4144 - val_loss: 69.2020
# Epoch 106/300
# 320/320 [==============================] - 5s 15ms/step - loss: 7.3622 - val_loss: 67.3448
# Epoch 107/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.8475 - val_loss: 67.0970
# Epoch 108/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.8103 - val_loss: 66.8607
# Epoch 109/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.7576 - val_loss: 66.8317
# Epoch 110/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.5023 - val_loss: 67.3177
# Epoch 111/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.4206 - val_loss: 67.7978
# Epoch 112/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.7066 - val_loss: 67.1363
# Epoch 113/300
# 320/320 [==============================] - 5s 14ms/step - loss: 5.5552 - val_loss: 66.9722
# Epoch 114/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.9278 - val_loss: 66.9118
# Epoch 115/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.7341 - val_loss: 67.3907
# Epoch 116/300
# 320/320 [==============================] - 5s 14ms/step - loss: 4.5936 - val_loss: 66.8298
# Epoch 117/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.1070 - val_loss: 68.0210
# Epoch 118/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.6463 - val_loss: 67.2624
# Epoch 119/300
# 320/320 [==============================] - 5s 14ms/step - loss: 4.8858 - val_loss: 66.5245
# Epoch 120/300
# 320/320 [==============================] - 5s 14ms/step - loss: 4.4944 - val_loss: 65.8720
# Epoch 121/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.1361 - val_loss: 66.6743
# Epoch 122/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.0050 - val_loss: 66.4252
# Epoch 123/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.2044 - val_loss: 65.8367
# Epoch 124/300
# 320/320 [==============================] - 5s 14ms/step - loss: 4.6630 - val_loss: 66.5549
# Epoch 125/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.8573 - val_loss: 67.0690
# Epoch 126/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.9034 - val_loss: 66.1555
# Epoch 127/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.4340 - val_loss: 67.6754
# Epoch 128/300
# 320/320 [==============================] - 5s 15ms/step - loss: 6.1313 - val_loss: 67.0354
# Epoch 129/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.9770 - val_loss: 66.3266
# Epoch 130/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.4110 - val_loss: 65.8439
# Epoch 131/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.5026 - val_loss: 65.0319
# Epoch 132/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.4664 - val_loss: 67.5379
# Epoch 133/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.7778 - val_loss: 66.0643
# Epoch 134/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.6463 - val_loss: 65.3775
# Epoch 135/300
# 320/320 [==============================] - 5s 14ms/step - loss: 4.7904 - val_loss: 66.7068
# Epoch 136/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.4383 - val_loss: 66.2402
# Epoch 137/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.8262 - val_loss: 65.7369
# Epoch 138/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.3179 - val_loss: 65.5972
# Epoch 139/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.4811 - val_loss: 65.7375
# Epoch 140/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.1135 - val_loss: 66.4371
# Epoch 141/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.7039 - val_loss: 65.9696
# Epoch 142/300
# 320/320 [==============================] - 5s 14ms/step - loss: 4.4103 - val_loss: 66.3878
# Epoch 143/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.5665 - val_loss: 66.2227
# Epoch 144/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.6167 - val_loss: 65.7668
# Epoch 145/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.1333 - val_loss: 66.4538
# Epoch 146/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.1286 - val_loss: 65.6980
# Epoch 147/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.7228 - val_loss: 65.4842
# Epoch 148/300
# 320/320 [==============================] - 5s 14ms/step - loss: 4.5815 - val_loss: 65.2850
# Epoch 149/300
# 320/320 [==============================] - 5s 15ms/step - loss: 3.9213 - val_loss: 65.1879
# Epoch 150/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.2273 - val_loss: 65.6247
# Epoch 151/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.1852 - val_loss: 65.1715
# Epoch 152/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.4352 - val_loss: 66.1723
# Epoch 153/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.7770 - val_loss: 65.6018
# Epoch 154/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.5846 - val_loss: 65.2387
# Epoch 155/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.2170 - val_loss: 65.1785
# Epoch 156/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.1845 - val_loss: 65.4433
# Epoch 157/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.2748 - val_loss: 65.3691
# Epoch 158/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.6528 - val_loss: 65.0805
# Epoch 159/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.3908 - val_loss: 64.5550
# Epoch 160/300
# 320/320 [==============================] - 5s 15ms/step - loss: 3.6355 - val_loss: 64.6217
# Epoch 161/300
# 320/320 [==============================] - 5s 15ms/step - loss: 3.8819 - val_loss: 65.0840
# Epoch 162/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.0071 - val_loss: 64.7505
# Epoch 163/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.7852 - val_loss: 65.5713
# Epoch 164/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.9430 - val_loss: 65.4300
# Epoch 165/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.0053 - val_loss: 64.6471
# Epoch 166/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.0823 - val_loss: 65.0873
# Epoch 167/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.1061 - val_loss: 65.3812
# Epoch 168/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.3683 - val_loss: 66.2706
# Epoch 169/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.9480 - val_loss: 65.2183
# Epoch 170/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.6744 - val_loss: 64.7556
# Epoch 171/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.8961 - val_loss: 65.0592
# Epoch 172/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.7534 - val_loss: 64.6209
# Epoch 173/300
# 320/320 [==============================] - 5s 14ms/step - loss: 4.1090 - val_loss: 64.9647
# Epoch 174/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.2564 - val_loss: 64.2837
# Epoch 175/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.6034 - val_loss: 65.2102
# Epoch 176/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.6045 - val_loss: 66.2693
# Epoch 177/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.1797 - val_loss: 66.1058
# Epoch 178/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.7639 - val_loss: 66.3567
# Epoch 179/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.3986 - val_loss: 65.8200
# Epoch 180/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.1560 - val_loss: 65.6842
# Epoch 181/300
# 320/320 [==============================] - 5s 15ms/step - loss: 6.2146 - val_loss: 66.4346
# Epoch 182/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.1734 - val_loss: 66.2059
# Epoch 183/300
# 320/320 [==============================] - 5s 15ms/step - loss: 8.7973 - val_loss: 67.6366
# Epoch 184/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.9025 - val_loss: 65.5494
# Epoch 185/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.3123 - val_loss: 66.0270
# Epoch 186/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.7490 - val_loss: 66.1730
# Epoch 187/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.4826 - val_loss: 65.6981
# Epoch 188/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.4121 - val_loss: 67.3278
# Epoch 189/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.5591 - val_loss: 66.5249
# Epoch 190/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.7238 - val_loss: 65.9557
# Epoch 191/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.4385 - val_loss: 65.8504
# Epoch 192/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.4866 - val_loss: 66.7093
# Epoch 193/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.0282 - val_loss: 66.6583
# Epoch 194/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.2683 - val_loss: 66.5723
# Epoch 195/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.7811 - val_loss: 65.7497
# Epoch 196/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.6302 - val_loss: 66.0160
# Epoch 197/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.9434 - val_loss: 65.8371
# Epoch 198/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.2497 - val_loss: 66.8572
# Epoch 199/300
# 320/320 [==============================] - 5s 15ms/step - loss: 6.2225 - val_loss: 67.0415
# Epoch 200/300
# 320/320 [==============================] - 5s 15ms/step - loss: 6.8092 - val_loss: 66.7603
# Epoch 201/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.8699 - val_loss: 66.3928
# Epoch 202/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.0140 - val_loss: 65.9364
# Epoch 203/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.0591 - val_loss: 66.2639
# Epoch 204/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.6094 - val_loss: 66.2213
# Epoch 205/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.6274 - val_loss: 66.5085
# Epoch 206/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.2027 - val_loss: 66.0490
# Epoch 207/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.5476 - val_loss: 67.0737
# Epoch 208/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.7245 - val_loss: 66.1798
# Epoch 209/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.4313 - val_loss: 66.1479
# Epoch 210/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.5248 - val_loss: 65.9565
# Epoch 211/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.6447 - val_loss: 66.2288
# Epoch 212/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.7948 - val_loss: 66.6380
# Epoch 213/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.1961 - val_loss: 65.8374
# Epoch 214/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.1476 - val_loss: 66.9907
# Epoch 215/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.3779 - val_loss: 66.2683
# Epoch 216/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.1919 - val_loss: 65.7960
# Epoch 217/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.5149 - val_loss: 66.0963
# Epoch 218/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.5975 - val_loss: 66.8784
# Epoch 219/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.6741 - val_loss: 66.0110
# Epoch 220/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.1456 - val_loss: 65.7634
# Epoch 221/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.3660 - val_loss: 65.3489
# Epoch 222/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.6264 - val_loss: 66.1364
# Epoch 223/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.0482 - val_loss: 65.9950
# Epoch 224/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.9618 - val_loss: 65.4815
# Epoch 225/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.9648 - val_loss: 65.7374
# Epoch 226/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.5954 - val_loss: 65.8618
# Epoch 227/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.6752 - val_loss: 66.6103
# Epoch 228/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.3207 - val_loss: 66.0160
# Epoch 229/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.4798 - val_loss: 65.9027
# Epoch 230/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.7425 - val_loss: 66.1381
# Epoch 231/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.3971 - val_loss: 65.4878
# Epoch 232/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.8830 - val_loss: 65.9495
# Epoch 233/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.7310 - val_loss: 65.8515
# Epoch 234/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.3772 - val_loss: 66.3093
# Epoch 235/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.3870 - val_loss: 65.4866
# Epoch 236/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.9432 - val_loss: 67.1440
# Epoch 237/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.7083 - val_loss: 65.4455
# Epoch 238/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.7157 - val_loss: 66.4381
# Epoch 239/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.6742 - val_loss: 65.4307
# Epoch 240/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.9155 - val_loss: 65.4280
# Epoch 241/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.2634 - val_loss: 65.9860
# Epoch 242/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.7658 - val_loss: 65.1964
# Epoch 243/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.0962 - val_loss: 66.4201
# Epoch 244/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.8260 - val_loss: 65.6467
# Epoch 245/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.6105 - val_loss: 65.5323
# Epoch 246/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.4873 - val_loss: 66.1497
# Epoch 247/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.5944 - val_loss: 66.0014
# Epoch 248/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.1811 - val_loss: 65.1962
# Epoch 249/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.7690 - val_loss: 65.5621
# Epoch 250/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.3400 - val_loss: 65.6470
# Epoch 251/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.8533 - val_loss: 65.0370
# Epoch 252/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.5401 - val_loss: 65.7361
# Epoch 253/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.5644 - val_loss: 65.6348
# Epoch 254/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.8653 - val_loss: 65.4570
# Epoch 255/300
# 320/320 [==============================] - 5s 15ms/step - loss: 6.3520 - val_loss: 65.5655
# Epoch 256/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.3454 - val_loss: 66.6850
# Epoch 257/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.8124 - val_loss: 65.7804
# Epoch 258/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.4177 - val_loss: 65.0269
# Epoch 259/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.2404 - val_loss: 65.7060
# Epoch 260/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.6634 - val_loss: 65.6986
# Epoch 261/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.6555 - val_loss: 66.6064
# Epoch 262/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.5211 - val_loss: 66.2878
# Epoch 263/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.7777 - val_loss: 65.2852
# Epoch 264/300
# 320/320 [==============================] - 5s 15ms/step - loss: 6.0056 - val_loss: 65.9577
# Epoch 265/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.3837 - val_loss: 65.8372
# Epoch 266/300
# 320/320 [==============================] - 5s 15ms/step - loss: 3.9652 - val_loss: 65.3941
# Epoch 267/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.4957 - val_loss: 66.3729
# Epoch 268/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.3926 - val_loss: 66.3488
# Epoch 269/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.4045 - val_loss: 65.9640
# Epoch 270/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.7509 - val_loss: 66.3387
# Epoch 271/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.9686 - val_loss: 65.3678
# Epoch 272/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.4251 - val_loss: 66.0885
# Epoch 273/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.3129 - val_loss: 65.4558
# Epoch 274/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.3448 - val_loss: 66.0765
# Epoch 275/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.7326 - val_loss: 65.6918
# Epoch 276/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.7308 - val_loss: 65.3179
# Epoch 277/300
# 320/320 [==============================] - 5s 15ms/step - loss: 7.1829 - val_loss: 65.6444
# Epoch 278/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.0248 - val_loss: 65.5199
# Epoch 279/300
# 320/320 [==============================] - 5s 15ms/step - loss: 3.9396 - val_loss: 66.2100
# Epoch 280/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.7420 - val_loss: 66.6188
# Epoch 281/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.5709 - val_loss: 65.6376
# Epoch 282/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.1309 - val_loss: 66.2651
# Epoch 283/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.5846 - val_loss: 65.6037
# Epoch 284/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.3732 - val_loss: 65.6936
# Epoch 285/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.7179 - val_loss: 65.6848
# Epoch 286/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.5054 - val_loss: 65.6927
# Epoch 287/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.2190 - val_loss: 68.9744
# Epoch 288/300
# 320/320 [==============================] - 5s 15ms/step - loss: 6.8407 - val_loss: 66.6289
# Epoch 289/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.5208 - val_loss: 65.3382
# Epoch 290/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.4319 - val_loss: 65.2479
# Epoch 291/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.2355 - val_loss: 65.5885
# Epoch 292/300
# 320/320 [==============================] - 5s 15ms/step - loss: 3.8466 - val_loss: 65.3259
# Epoch 293/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.9468 - val_loss: 66.0796
# Epoch 294/300
# 320/320 [==============================] - 5s 15ms/step - loss: 5.4128 - val_loss: 65.9178
# Epoch 295/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.0982 - val_loss: 65.3090
# Epoch 296/300
# 320/320 [==============================] - 5s 15ms/step - loss: 3.7764 - val_loss: 65.4538
# Epoch 297/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.4584 - val_loss: 66.9164
# Epoch 298/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.5526 - val_loss: 65.4735
# Epoch 299/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.4291 - val_loss: 65.6189
# Epoch 300/300
# 320/320 [==============================] - 5s 15ms/step - loss: 4.4309 - val_loss: 65.2250

# %%
model.evaluate(x_train, y_train)
# Out:
# 40/40 [==============================] - 0s 10ms/step - loss: 8.3052
# 8.305209159851074

# %%
model.evaluate(x_train_augmented, y_train_augmented)
# Out:
# 160/160 [==============================] - 1s 8ms/step - loss: 8.1392
# 8.139188766479492

# %%
model.evaluate(x_val, y_val)
# Out:
# 8/8 [==============================] - 0s 7ms/step - loss: 129.5187
# 129.5186767578125

# %%
y_pred = model.predict(x_train)
print_data_detection(x_train, y_pred, image_size=IMAGE_SIZE)

# %%
y_val_pred = model.predict(x_val)
print_data_detection(x_val, y_val_pred, image_size=IMAGE_SIZE)

# %%
# Analyse des résultats : courbes d'évolution de la fonction de perte, et de l'IoU des boîtes englobantes ainsi que de l'accuracy des classes prédites
plot_training_analysis(history, metric='loss')

# %% [markdown]
# Bien que l'entraînement soit assez instable, vous devriez arriver à faire baisser la perte d'entrainement à des valeurs assez basses (< 10). A ce moment là, vous pouvez visualiser la prédiction du réseau sur l'ensemble d'entraînement et vous persuader que le réseau a appris quelque chose !
#
# En revanche le sur-apprentissage est très important. A nouveau vous pouvez tester les techniques indiquées dans la première partie et essayer de limiter ce sur-apprentissage !

# %% [markdown]
# Pour améliorer les résultats, et réduire l'overfitting, nous avons
#
#
# *   **Ajouté du Batchnorm (surtout pour rendre l'entraînement plus régulier)**
# *   **Ajouté de la régularisation dans les couches**
# *   **Ajouté de la data-augmentation avec imgaug**
# *   **Nous avons tenté d'ajouter du dropout mais le résultat a été dramatique**
#
#
# Val_loss finale : 65.
